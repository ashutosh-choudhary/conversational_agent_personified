# %%
import string
import glob
import nltk

# %% [markdown]
# # Copy all dialogs to one file

# %%
all_dialogs = ""
replace_punctuation = string.maketrans(string.punctuation, ' '*len(string.punctuation))
for fname in glob.iglob('../data/clean_data/*/*.txt'):
    print fname
    prev_char = ''
    for line in open(fname):
        line = line.strip()
        parts = line.split(': ')
        character = parts[0]
        dialog = ' '.join(parts[1:])
        dialog = dialog.lower()
        dialog = dialog.translate(replace_punctuation)
        if character != prev_char:
            all_dialogs += dialog + '\n'
        else:
            all_dialogs += dialog + ' '
        prev_char = character
with open('../res/all_dialogs.txt', 'w') as f:
    f.write(all_dialogs)
# Out:
# ../data/clean_data/F/Fair Game.txt
# ../data/clean_data/F/Fast Times at Ridgemont High.txt
# ../data/clean_data/F/Five Easy Pieces.txt
# ../data/clean_data/F/Frozen (Disney).txt
# ../data/clean_data/F/Fantastic Four.txt
# ../data/clean_data/F/Field of Dreams.txt
# ../data/clean_data/F/Fabulous Baker Boys, The.txt
# ../data/clean_data/F/Frozen.txt
# ../data/clean_data/F/Flintstones, The.txt
# ../data/clean_data/F/Fargo.txt
# ../data/clean_data/F/Fatal Instinct.txt
# ../data/clean_data/F/Fright Night.txt
# ../data/clean_data/F/From Dusk Till Dawn.txt
# ../data/clean_data/F/Final Destination.txt
# ../data/clean_data/F/Friday the 13th.txt
# ../data/clean_data/F/Flight.txt
# ../data/clean_data/F/Flash Gordon.txt
# ../data/clean_data/F/Fantastic Mr Fox.txt
# ../data/clean_data/F/Freaked.txt
# ../data/clean_data/F/Forrest Gump.txt
# ../data/clean_data/F/Fracture.txt
# ../data/clean_data/F/Frances.txt
# ../data/clean_data/F/Family Man, The.txt
# ../data/clean_data/F/Ferris Bueller's Day Off.txt
# ../data/clean_data/F/Fear and Loathing in Las Vegas.txt
# ../data/clean_data/F/Funny People.txt
# ../data/clean_data/F/Frankenstein.txt
# ../data/clean_data/F/Frankenweenie.txt
# ../data/clean_data/F/Fright Night (1985).txt
# ../data/clean_data/F/Fruitvale Station.txt
# ../data/clean_data/F/Final Destination 2.txt
# ../data/clean_data/F/Fight Club.txt
# ../data/clean_data/F/Finding Nemo.txt
# ../data/clean_data/F/Foxcatcher.txt
# ../data/clean_data/F/Four Rooms.txt
# ../data/clean_data/F/Fifth Element, The.txt
# ../data/clean_data/F/Frozen River.txt
# ../data/clean_data/F/Face Off.txt
# ../data/clean_data/F/Feast.txt
# ../data/clean_data/F/Fugitive, The.txt
# ../data/clean_data/F/Freddy vs. Jason.txt
# ../data/clean_data/F/Fault in Our Stars, The.txt
# ../data/clean_data/F/French Connection, The.txt
# ../data/clean_data/F/Friday the 13th Part VIII Jason Takes Manhattan.txt
# ../data/clean_data/F/Fighter, The.txt
# ../data/clean_data/F/Frequency.txt
# ../data/clean_data/F/From Here to Eternity.txt
# ../data/clean_data/K/Killing Zoe.txt
# ../data/clean_data/K/Kill Bill Volume 1 & 2.txt
# ../data/clean_data/K/Kids Are All Right, The.txt
# ../data/clean_data/K/Kate & Leopold.txt
# ../data/clean_data/K/Kalifornia.txt
# ../data/clean_data/K/King Kong.txt
# ../data/clean_data/K/Kramer vs Kramer.txt
# ../data/clean_data/K/Kill Your Darlings.txt
# ../data/clean_data/K/King of Comedy, The.txt
# ../data/clean_data/K/King's Speech, The.txt
# ../data/clean_data/K/Kundun.txt
# ../data/clean_data/K/Kung Fu Panda.txt
# ../data/clean_data/K/Knocked Up.txt
# ../data/clean_data/K/Kafka.txt
# ../data/clean_data/K/Klute.txt
# ../data/clean_data/K/Kids.txt
# ../data/clean_data/K/Kingdom, The.txt
# ../data/clean_data/X/xXx.txt
# ../data/clean_data/X/X-Men.txt
# ../data/clean_data/X/X-Men Origins Wolverine.txt
# ../data/clean_data/X/X-Files Fight the Future, The.txt
# ../data/clean_data/U/Unknown.txt
# ../data/clean_data/U/Unbreakable.txt
# ../data/clean_data/U/Ugly Truth, The.txt
# ../data/clean_data/U/Usual Suspects, The.txt
# ../data/clean_data/U/Up.txt
# ../data/clean_data/U/Under Fire.txt
# ../data/clean_data/U/Up in the Air.txt
# ../data/clean_data/U/U Turn.txt
# ../data/clean_data/U/Un Singe en Hiver.txt
# ../data/clean_data/D/Departed, The.txt
# ../data/clean_data/D/Deep Rising.txt
# ../data/clean_data/D/Dear White People.txt
# ../data/clean_data/D/Darkman.txt
# ../data/clean_data/D/Devil in a Blue Dress.txt
# ../data/clean_data/D/Drag Me to Hell.txt
# ../data/clean_data/D/Dumb and Dumber.txt
# ../data/clean_data/D/Do The Right Thing.txt
# ../data/clean_data/D/Day of the Dead.txt
# ../data/clean_data/D/Day the Clown Cried, The.txt
# ../data/clean_data/D/Django Unchained.txt
# ../data/clean_data/D/Dallas Buyers Club.txt
# ../data/clean_data/D/Dead Poets Society.txt
# ../data/clean_data/D/Diner.txt
# ../data/clean_data/D/Deep Cover.txt
# ../data/clean_data/D/Donnie Brasco.txt
# ../data/clean_data/D/Drive Angry.txt
# ../data/clean_data/D/Date Night.txt
# ../data/clean_data/D/Deer Hunter, The.txt
# ../data/clean_data/D/Detroit Rock City.txt
# ../data/clean_data/D/Drive.txt
# ../data/clean_data/D/Devil's Advocate.txt
# ../data/clean_data/D/Dune.txt
# ../data/clean_data/D/Double Indemnity.txt
# ../data/clean_data/D/Disturbia.txt
# ../data/clean_data/D/Damned United, The.txt
# ../data/clean_data/D/Defiance.txt
# ../data/clean_data/D/Dave Barry's Complete Guide to Guys.txt
# ../data/clean_data/D/Duck Soup.txt
# ../data/clean_data/D/Dances with Wolves.txt
# ../data/clean_data/D/Dry White Season, A.txt
# ../data/clean_data/D/Day the Earth Stood Still, The.txt
# ../data/clean_data/D/Dark Star.txt
# ../data/clean_data/D/Die Hard.txt
# ../data/clean_data/D/Descendants, The.txt
# ../data/clean_data/D/Debt, The.txt
# ../data/clean_data/D/Death at a Funeral.txt
# ../data/clean_data/D/Dark Knight Rises, The.txt
# ../data/clean_data/D/Despicable Me 2.txt
# ../data/clean_data/D/Distinguished Gentleman, The.txt
# ../data/clean_data/D/Drop Dead Gorgeous.txt
# ../data/clean_data/D/Dogma.txt
# ../data/clean_data/D/Death to Smoochy.txt
# ../data/clean_data/D/Dragonslayer.txt
# ../data/clean_data/D/Dog Day Afternoon.txt
# ../data/clean_data/D/Deception.txt
# ../data/clean_data/D/Dark City.txt
# ../data/clean_data/D/Die Hard 2.txt
# ../data/clean_data/D/Doors, The.txt
# ../data/clean_data/O/Ordinary People.txt
# ../data/clean_data/O/Ocean's Twelve.txt
# ../data/clean_data/O/Orgy of the Dead.txt
# ../data/clean_data/O/Out of Sight.txt
# ../data/clean_data/O/Obsessed.txt
# ../data/clean_data/O/Only God Forgives.txt
# ../data/clean_data/O/Other Boleyn Girl, The.txt
# ../data/clean_data/O/Oblivion.txt
# ../data/clean_data/O/Office Space.txt
# ../data/clean_data/O/Ocean's Eleven.txt
# ../data/clean_data/O/One Flew Over the Cuckoo's Nest.txt
# ../data/clean_data/O/Observe and Report.txt
# ../data/clean_data/O/Orphan.txt
# ../data/clean_data/Q/Quantum Project.txt
# ../data/clean_data/Q/Queen, The.txt
# ../data/clean_data/Q/Queen of the Damned.txt
# ../data/clean_data/R/Rambling Rose.txt
# ../data/clean_data/R/Robin Hood Prince of Thieves.txt
# ../data/clean_data/R/Roughshod.txt
# ../data/clean_data/R/Revolutionary Road.txt
# ../data/clean_data/R/Rambo First Blood II The Mission.txt
# ../data/clean_data/R/Rush Hour 2.txt
# ../data/clean_data/R/Reindeer Games.txt
# ../data/clean_data/R/Raging Bull.txt
# ../data/clean_data/R/Relic, The.txt
# ../data/clean_data/R/Romeo & Juliet.txt
# ../data/clean_data/R/Resident Evil.txt
# ../data/clean_data/R/Red Riding Hood.txt
# ../data/clean_data/R/Reader, The.txt
# ../data/clean_data/R/Rock, The.txt
# ../data/clean_data/R/Revenant, The.txt
# ../data/clean_data/R/Roommate, The.txt
# ../data/clean_data/R/Replacements, The.txt
# ../data/clean_data/R/Raising Arizona.txt
# ../data/clean_data/R/Rachel Getting Married.txt
# ../data/clean_data/R/Rebel Without A Cause.txt
# ../data/clean_data/R/RocknRolla.txt
# ../data/clean_data/R/Ringu.txt
# ../data/clean_data/R/Remember Me.txt
# ../data/clean_data/R/Rust and Bone.txt
# ../data/clean_data/R/Ruins, The.txt
# ../data/clean_data/R/Rush.txt
# ../data/clean_data/R/Rise of the Guardians.txt
# ../data/clean_data/R/Rear Window.txt
# ../data/clean_data/R/Ronin.txt
# ../data/clean_data/R/Reservoir Dogs.txt
# ../data/clean_data/R/Rocky Horror Picture Show, The.txt
# ../data/clean_data/R/Rush Hour.txt
# ../data/clean_data/R/Rocky.txt
# ../data/clean_data/R/Return of the Apes.txt
# ../data/clean_data/R/Runaway Bride.txt
# ../data/clean_data/R/RKO 281.txt
# ../data/clean_data/R/Repo Man.txt
# ../data/clean_data/R/Rise of the Planet of the Apes.txt
# ../data/clean_data/M/Mad Max 2 The Road Warrior.txt
# ../data/clean_data/M/Meet John Doe.txt
# ../data/clean_data/M/Midnight Express.txt
# ../data/clean_data/M/Majestic, The (The Bijou).txt
# ../data/clean_data/M/Men in Black.txt
# ../data/clean_data/M/Mini's First Time.txt
# ../data/clean_data/M/Mariachi, El.txt
# ../data/clean_data/M/Man On Fire.txt
# ../data/clean_data/M/Monte Carlo.txt
# ../data/clean_data/M/Men in Black 3.txt
# ../data/clean_data/M/Malcolm X.txt
# ../data/clean_data/M/Moonrise Kingdom.txt
# ../data/clean_data/M/My Week with Marilyn.txt
# ../data/clean_data/M/Machine Gun Preacher.txt
# ../data/clean_data/M/Margaret.txt
# ../data/clean_data/M/Moonstruck.txt
# ../data/clean_data/M/Mr Blandings Builds His Dream House.txt
# ../data/clean_data/M/Max Payne.txt
# ../data/clean_data/M/Mute Witness.txt
# ../data/clean_data/M/Music of the Heart.txt
# ../data/clean_data/M/Mighty Morphin Power Rangers The Movie.txt
# ../data/clean_data/M/Master and Commander.txt
# ../data/clean_data/M/Manhattan Murder Mystery.txt
# ../data/clean_data/M/Mystery Men.txt
# ../data/clean_data/M/Mission Impossible II.txt
# ../data/clean_data/M/Man in the Iron Mask.txt
# ../data/clean_data/M/Man Who Knew Too Much, The.txt
# ../data/clean_data/M/Mirrors.txt
# ../data/clean_data/M/Mission to Mars.txt
# ../data/clean_data/M/Machete.txt
# ../data/clean_data/M/Metro.txt
# ../data/clean_data/M/Mask, The.txt
# ../data/clean_data/M/Marley & Me.txt
# ../data/clean_data/M/Magnolia.txt
# ../data/clean_data/M/Mud.txt
# ../data/clean_data/M/My Best Friend's Wedding.txt
# ../data/clean_data/M/Midnight Cowboy.txt
# ../data/clean_data/M/Mr Brooks.txt
# ../data/clean_data/M/Mean Streets.txt
# ../data/clean_data/M/Mechanic, The.txt
# ../data/clean_data/M/Miami Vice.txt
# ../data/clean_data/M/Mimic.txt
# ../data/clean_data/M/Man Who Wasn't There, The.txt
# ../data/clean_data/M/Moon.txt
# ../data/clean_data/M/Matrix Reloaded, The.txt
# ../data/clean_data/M/Minority Report.txt
# ../data/clean_data/M/Men Who Stare at Goats, The.txt
# ../data/clean_data/M/Margot at the Wedding.txt
# ../data/clean_data/M/Major League.txt
# ../data/clean_data/M/Midnight in Paris.txt
# ../data/clean_data/M/Man on the Moon.txt
# ../data/clean_data/M/Manchurian Candidate, The.txt
# ../data/clean_data/M/Mr Deeds Goes to Town.txt
# ../data/clean_data/M/Margin Call.txt
# ../data/clean_data/M/Mumford.txt
# ../data/clean_data/M/Megamind.txt
# ../data/clean_data/M/Meet Joe Black.txt
# ../data/clean_data/M/Milk.txt
# ../data/clean_data/M/Martha Marcy May Marlene.txt
# ../data/clean_data/M/Mission Impossible.txt
# ../data/clean_data/M/Misery.txt
# ../data/clean_data/M/Man Trouble.txt
# ../data/clean_data/M/Monkeybone.txt
# ../data/clean_data/M/Moneyball.txt
# ../data/clean_data/M/Manhunter.txt
# ../data/clean_data/M/Mrs. Brown.txt
# ../data/clean_data/M/Master, The.txt
# ../data/clean_data/M/Memento.txt
# ../data/clean_data/M/Matrix, The.txt
# ../data/clean_data/M/Malibu's Most Wanted.txt
# ../data/clean_data/M/Marty.txt
# ../data/clean_data/M/Miracle Worker, The.txt
# ../data/clean_data/M/Mulholland Drive.txt
# ../data/clean_data/M/My Girl.txt
# ../data/clean_data/M/My Mother Dreams the Satan's Disciples in New York.txt
# ../data/clean_data/M/Mummy, The.txt
# ../data/clean_data/N/Nines, The.txt
# ../data/clean_data/N/Natural Born Killers.txt
# ../data/clean_data/N/Nashville.txt
# ../data/clean_data/N/New York Minute.txt
# ../data/clean_data/N/Newsies.txt
# ../data/clean_data/N/Next Friday.txt
# ../data/clean_data/N/Ninotchka.txt
# ../data/clean_data/N/Notting Hill.txt
# ../data/clean_data/N/Nick of Time.txt
# ../data/clean_data/N/No Strings Attached.txt
# ../data/clean_data/N/Nine.txt
# ../data/clean_data/N/Nightmare on Elm Street The Final Chapter.txt
# ../data/clean_data/N/No Country for Old Men.txt
# ../data/clean_data/N/Nurse Betty.txt
# ../data/clean_data/N/Nightmare on Elm Street, A.txt
# ../data/clean_data/N/Next Three Days, The.txt
# ../data/clean_data/N/Ninja Assassin.txt
# ../data/clean_data/N/Next.txt
# ../data/clean_data/N/Ni vu ni connu.txt
# ../data/clean_data/N/Nightmare Before Christmas, The.txt
# ../data/clean_data/S/Sleepy Hollow.txt
# ../data/clean_data/S/Snow Falling On Cedars.txt
# ../data/clean_data/S/Starship Troopers.txt
# ../data/clean_data/S/Scarface.txt
# ../data/clean_data/S/Super 8.txt
# ../data/clean_data/S/Source Code.txt
# ../data/clean_data/S/Strange Days.txt
# ../data/clean_data/S/Sex, Lies and Videotape.txt
# ../data/clean_data/S/Synecdoche, New York.txt
# ../data/clean_data/S/Slither.txt
# ../data/clean_data/S/Storytelling.txt
# ../data/clean_data/S/Sex and the City.txt
# ../data/clean_data/S/Star Trek The Motion Picture.txt
# ../data/clean_data/S/Sessions, The.txt
# ../data/clean_data/S/Syriana.txt
# ../data/clean_data/S/Sleepless in Seattle.txt
# ../data/clean_data/S/Starman.txt
# ../data/clean_data/S/Silver Bullet.txt
# ../data/clean_data/S/Shrek the Third.txt
# ../data/clean_data/S/Star Trek Generations.txt
# ../data/clean_data/S/Shallow Grave.txt
# ../data/clean_data/S/Scream.txt
# ../data/clean_data/S/Serenity.txt
# ../data/clean_data/S/Spare Me.txt
# ../data/clean_data/S/Single White Female.txt
# ../data/clean_data/S/Shampoo.txt
# ../data/clean_data/S/Salton Sea, The.txt
# ../data/clean_data/S/Scott Pilgrim vs the World.txt
# ../data/clean_data/S/Shame.txt
# ../data/clean_data/S/She's Out of My League.txt
# ../data/clean_data/S/Shakespeare in Love.txt
# ../data/clean_data/S/Surfer King, The.txt
# ../data/clean_data/S/Speed Racer.txt
# ../data/clean_data/S/Suspect Zero.txt
# ../data/clean_data/S/Sense and Sensibility.txt
# ../data/clean_data/S/Star Wars The Force Awakens.txt
# ../data/clean_data/S/Sweet Smell of Success.txt
# ../data/clean_data/S/Silence of the Lambs.txt
# ../data/clean_data/S/Star Trek First Contact.txt
# ../data/clean_data/S/Sunset Blvd..txt
# ../data/clean_data/S/Social Network, The.txt
# ../data/clean_data/S/Sideways.txt
# ../data/clean_data/S/St. Elmo's Fire.txt
# ../data/clean_data/S/Snow White and the Huntsman.txt
# ../data/clean_data/S/Sweet Hereafter, The.txt
# ../data/clean_data/S/Silver Linings Playbook.txt
# ../data/clean_data/S/Sixth Sense, The.txt
# ../data/clean_data/S/Sugar and Spice.txt
# ../data/clean_data/S/Saving Mr. Banks.txt
# ../data/clean_data/S/Sling Blade.txt
# ../data/clean_data/S/Semi-Pro.txt
# ../data/clean_data/S/Superbad.txt
# ../data/clean_data/S/S. Darko.txt
# ../data/clean_data/S/Shining, The.txt
# ../data/clean_data/S/Shipping News, The.txt
# ../data/clean_data/S/Strangers on a Train.txt
# ../data/clean_data/S/Smokin' Aces.txt
# ../data/clean_data/S/Saw.txt
# ../data/clean_data/S/Sexual Life.txt
# ../data/clean_data/S/Six Degrees of Separation.txt
# ../data/clean_data/S/Star Wars The Empire Strikes Back.txt
# ../data/clean_data/S/Snatch.txt
# ../data/clean_data/S/Slumdog Millionaire.txt
# ../data/clean_data/S/Seventh Seal, The.txt
# ../data/clean_data/S/Saving Private Ryan.txt
# ../data/clean_data/S/Sphere.txt
# ../data/clean_data/S/Stir of Echoes.txt
# ../data/clean_data/S/Supergirl.txt
# ../data/clean_data/S/Spider-Man.txt
# ../data/clean_data/S/Something's Gotta Give.txt
# ../data/clean_data/S/Siege, The.txt
# ../data/clean_data/S/Station West.txt
# ../data/clean_data/S/Soldier.txt
# ../data/clean_data/S/Sister Act.txt
# ../data/clean_data/S/Shawshank Redemption, The.txt
# ../data/clean_data/S/Spanglish.txt
# ../data/clean_data/S/Schindler's List.txt
# ../data/clean_data/S/Shivers.txt
# ../data/clean_data/S/Stepmom.txt
# ../data/clean_data/S/Solaris.txt
# ../data/clean_data/S/Signs.txt
# ../data/clean_data/S/Star Trek II The Wrath of Khan.txt
# ../data/clean_data/S/Someone To Watch Over Me.txt
# ../data/clean_data/S/Sugar.txt
# ../data/clean_data/S/Se7en.txt
# ../data/clean_data/S/Surrogates.txt
# ../data/clean_data/S/Star Wars A New Hope.txt
# ../data/clean_data/S/Star Trek.txt
# ../data/clean_data/S/So I Married an Axe Murderer.txt
# ../data/clean_data/S/Sherlock Holmes.txt
# ../data/clean_data/S/Stuntman, The.txt
# ../data/clean_data/S/Smashed.txt
# ../data/clean_data/S/Swordfish.txt
# ../data/clean_data/S/South Park.txt
# ../data/clean_data/S/Star Wars Return of the Jedi.txt
# ../data/clean_data/S/Searchers, The.txt
# ../data/clean_data/S/Star Trek Nemesis.txt
# ../data/clean_data/S/Shrek.txt
# ../data/clean_data/S/Sunshine Cleaning.txt
# ../data/clean_data/S/State and Main.txt
# ../data/clean_data/S/Simone.txt
# ../data/clean_data/S/Scream 3.txt
# ../data/clean_data/S/Sting, The.txt
# ../data/clean_data/S/Sandlot Kids, The.txt
# ../data/clean_data/S/Scream 2.txt
# ../data/clean_data/S/Save the Last Dance.txt
# ../data/clean_data/S/Shifty.txt
# ../data/clean_data/S/Swingers.txt
# ../data/clean_data/S/Serial Mom.txt
# ../data/clean_data/S/Spartan.txt
# ../data/clean_data/S/Star Wars Attack of the Clones.txt
# ../data/clean_data/S/Sweeney Todd The Demon Barber of Fleet Street.txt
# ../data/clean_data/Z/Zerophilia.txt
# ../data/clean_data/Z/Zero Dark Thirty.txt
# ../data/clean_data/H/Happy Feet.txt
# ../data/clean_data/H/Haunting, The.txt
# ../data/clean_data/H/Hebrew Hammer, The.txt
# ../data/clean_data/H/Hanna.txt
# ../data/clean_data/H/How to Lose Friends & Alienate People.txt
# ../data/clean_data/H/Hostage.txt
# ../data/clean_data/H/Hard Rain.txt
# ../data/clean_data/H/His Girl Friday.txt
# ../data/clean_data/H/Henry's Crime.txt
# ../data/clean_data/H/Hitchhiker's Guide to the Galaxy, The.txt
# ../data/clean_data/H/Heavenly Creatures.txt
# ../data/clean_data/H/Hitchcock.txt
# ../data/clean_data/H/Halloween The Curse of Michael Myers.txt
# ../data/clean_data/H/Happy Birthday, Wanda June.txt
# ../data/clean_data/H/Hangover, The.txt
# ../data/clean_data/H/Hannah and Her Sisters.txt
# ../data/clean_data/H/Hollow Man.txt
# ../data/clean_data/H/Hellbound Hellraiser II.txt
# ../data/clean_data/H/Help, The.txt
# ../data/clean_data/H/He's Just Not That Into You.txt
# ../data/clean_data/H/Heathers.txt
# ../data/clean_data/H/Horrible Bosses.txt
# ../data/clean_data/H/High Fidelity.txt
# ../data/clean_data/H/Hackers.txt
# ../data/clean_data/H/House of 1000 Corpses.txt
# ../data/clean_data/H/Hall Pass.txt
# ../data/clean_data/H/Hellraiser Hellseeker.txt
# ../data/clean_data/H/Her.txt
# ../data/clean_data/H/Human Nature.txt
# ../data/clean_data/H/How to Train Your Dragon.txt
# ../data/clean_data/H/Heavy Metal.txt
# ../data/clean_data/H/Hot Tub Time Machine.txt
# ../data/clean_data/H/Highlander.txt
# ../data/clean_data/H/Hunt for Red October, The.txt
# ../data/clean_data/H/Hannibal.txt
# ../data/clean_data/H/Heist.txt
# ../data/clean_data/H/Hospital, The.txt
# ../data/clean_data/H/How to Train Your Dragon 2.txt
# ../data/clean_data/H/Horse Whisperer, The.txt
# ../data/clean_data/H/Hellboy 2 The Golden Army.txt
# ../data/clean_data/H/Hesher.txt
# ../data/clean_data/H/Hudsucker Proxy, The.txt
# ../data/clean_data/H/Henry Fool.txt
# ../data/clean_data/H/Hudson Hawk.txt
# ../data/clean_data/H/Hellraiser 3 Hell on Earth.txt
# ../data/clean_data/H/Hellboy.txt
# ../data/clean_data/H/Hellraiser Deader.txt
# ../data/clean_data/H/Harold and Kumar Go to White Castle.txt
# ../data/clean_data/H/Hills Have Eyes, The.txt
# ../data/clean_data/H/Hotel Rwanda.txt
# ../data/clean_data/H/Hard to Kill.txt
# ../data/clean_data/H/Heat.txt
# ../data/clean_data/H/Hancock.txt
# ../data/clean_data/H/Honeydripper.txt
# ../data/clean_data/H/Hellraiser.txt
# ../data/clean_data/I/I am Sam.txt
# ../data/clean_data/I/I Spit on Your Grave.txt
# ../data/clean_data/I/Interstellar.txt
# ../data/clean_data/I/Iron Lady, The.txt
# ../data/clean_data/I/Independence Day.txt
# ../data/clean_data/I/Ice Storm, The.txt
# ../data/clean_data/I/Insider, The.txt
# ../data/clean_data/I/I Love You Phillip Morris.txt
# ../data/clean_data/I/I Still Know What You Did Last Summer.txt
# ../data/clean_data/I/It's Complicated.txt
# ../data/clean_data/I/I Am Number Four.txt
# ../data/clean_data/I/It Happened One Night.txt
# ../data/clean_data/I/I'll Do Anything.txt
# ../data/clean_data/I/Informant, The.txt
# ../data/clean_data/I/Inglourious Basterds.txt
# ../data/clean_data/I/Interview with the Vampire.txt
# ../data/clean_data/I/Intolerable Cruelty.txt
# ../data/clean_data/I/Inventing the Abbotts.txt
# ../data/clean_data/I/I, Robot.txt
# ../data/clean_data/I/Island, The.txt
# ../data/clean_data/I/In the Loop.txt
# ../data/clean_data/I/Indiana Jones and the Temple of Doom.txt
# ../data/clean_data/I/Invictus.txt
# ../data/clean_data/I/Insomnia.txt
# ../data/clean_data/I/Indiana Jones and the Last Crusade.txt
# ../data/clean_data/I/Italian Job, The.txt
# ../data/clean_data/I/It's a Wonderful Life.txt
# ../data/clean_data/I/Invention of Lying, The.txt
# ../data/clean_data/I/Into the Wild.txt
# ../data/clean_data/I/In the Bedroom.txt
# ../data/clean_data/I/Ides of March, The.txt
# ../data/clean_data/I/Indiana Jones IV.txt
# ../data/clean_data/I/Inception.txt
# ../data/clean_data/I/Insidious.txt
# ../data/clean_data/I/Indiana Jones and the Raiders of the Lost Ark.txt
# ../data/clean_data/I/Imaginarium of Doctor Parnassus, The.txt
# ../data/clean_data/0/15 Minutes.txt
# ../data/clean_data/0/12.txt
# ../data/clean_data/0/12 Years a Slave.txt
# ../data/clean_data/0/2001 A Space Odyssey.txt
# ../data/clean_data/0/8MM.txt
# ../data/clean_data/0/44 Inch Chest.txt
# ../data/clean_data/0/10 Things I Hate About You.txt
# ../data/clean_data/0/50-50.txt
# ../data/clean_data/0/48 Hrs..txt
# ../data/clean_data/0/500 Days of Summer.txt
# ../data/clean_data/0/127 Hours.txt
# ../data/clean_data/0/12 Monkeys.txt
# ../data/clean_data/0/2012.txt
# ../data/clean_data/0/12 and Holding.txt
# ../data/clean_data/0/9.txt
# ../data/clean_data/0/17 Again.txt
# ../data/clean_data/0/42.txt
# ../data/clean_data/0/30 Minutes or Less.txt
# ../data/clean_data/0/1492 Conquest of Paradise.txt
# ../data/clean_data/G/Getaway, The.txt
# ../data/clean_data/G/Get Carter.txt
# ../data/clean_data/G/Garden State.txt
# ../data/clean_data/G/Godfather.txt
# ../data/clean_data/G/Ghostbusters.txt
# ../data/clean_data/G/Godfather Part II.txt
# ../data/clean_data/G/Ghost Rider.txt
# ../data/clean_data/G/Game 6.txt
# ../data/clean_data/G/Godfather Part III, The.txt
# ../data/clean_data/G/Gravity.txt
# ../data/clean_data/G/Grand Hotel.txt
# ../data/clean_data/G/Grapes of Wrath, The.txt
# ../data/clean_data/G/Ghost World.txt
# ../data/clean_data/G/Game, The.txt
# ../data/clean_data/G/Gremlins 2.txt
# ../data/clean_data/G/Grosse Point Blank.txt
# ../data/clean_data/G/Ghost and the Darkness, The.txt
# ../data/clean_data/G/Gran Torino.txt
# ../data/clean_data/G/Grudge, The.txt
# ../data/clean_data/G/Girl with the Dragon Tattoo, The.txt
# ../data/clean_data/G/Graduate, The.txt
# ../data/clean_data/G/Gothika.txt
# ../data/clean_data/G/Green Mile, The.txt
# ../data/clean_data/G/G.I. Jane.txt
# ../data/clean_data/G/Grifters, The.txt
# ../data/clean_data/G/Gamer.txt
# ../data/clean_data/G/Gang Related.txt
# ../data/clean_data/G/Gremlins.txt
# ../data/clean_data/G/Get Low.txt
# ../data/clean_data/G/Gattaca.txt
# ../data/clean_data/G/Gangs of New York.txt
# ../data/clean_data/G/Good Will Hunting.txt
# ../data/clean_data/G/Godzilla.txt
# ../data/clean_data/G/Ginger Snaps.txt
# ../data/clean_data/G/Grand Theft Parsons.txt
# ../data/clean_data/G/Gandhi.txt
# ../data/clean_data/G/Gods and Monsters.txt
# ../data/clean_data/G/Groundhog Day.txt
# ../data/clean_data/G/G.I. Joe The Rise of Cobra.txt
# ../data/clean_data/G/Glengarry Glen Gross.txt
# ../data/clean_data/G/Ghost.txt
# ../data/clean_data/G/Ghostbusters 2.txt
# ../data/clean_data/G/Ghost Ship.txt
# ../data/clean_data/G/Go.txt
# ../data/clean_data/G/Gladiator.txt
# ../data/clean_data/G/Good Girl, The.txt
# ../data/clean_data/G/Gone in 60 Seconds.txt
# ../data/clean_data/E/Extract.txt
# ../data/clean_data/E/Easy A.txt
# ../data/clean_data/E/Eagle Eye.txt
# ../data/clean_data/E/English Patient, The.txt
# ../data/clean_data/E/eXistenZ.txt
# ../data/clean_data/E/Enemy of the State.txt
# ../data/clean_data/E/Excalibur.txt
# ../data/clean_data/E/Elizabeth The Golden Age.txt
# ../data/clean_data/E/Event Horizon.txt
# ../data/clean_data/E/Eastern Promises.txt
# ../data/clean_data/E/Elephant Man, The.txt
# ../data/clean_data/E/Eternal Sunshine of the Spotless Mind.txt
# ../data/clean_data/E/Entrapment.txt
# ../data/clean_data/E/Escape From New York.txt
# ../data/clean_data/E/Eight Legged Freaks.txt
# ../data/clean_data/E/Edward Scissorhands.txt
# ../data/clean_data/E/Ed TV.txt
# ../data/clean_data/E/Erin Brockovich.txt
# ../data/clean_data/E/Evil Dead II Dead by Dawn.txt
# ../data/clean_data/E/Escape From L.A..txt
# ../data/clean_data/E/Ed Wood.txt
# ../data/clean_data/E/Even Cowgirls Get the Blues.txt
# ../data/clean_data/E/Enough.txt
# ../data/clean_data/E/Election.txt
# ../data/clean_data/W/Woodsman, The.txt
# ../data/clean_data/W/Water for Elephants.txt
# ../data/clean_data/W/Wind Chill.txt
# ../data/clean_data/W/Win Win.txt
# ../data/clean_data/W/White Squall.txt
# ../data/clean_data/W/What Lies Beneath.txt
# ../data/clean_data/W/Wizard of Oz, The.txt
# ../data/clean_data/W/Warrior.txt
# ../data/clean_data/W/Wall Street Money Never Sleeps.txt
# ../data/clean_data/W/Wall-E.txt
# ../data/clean_data/W/World is not Enough, The.txt
# ../data/clean_data/W/Wonder Boys.txt
# ../data/clean_data/W/Wall Street.txt
# ../data/clean_data/W/Wag the Dog.txt
# ../data/clean_data/W/Whiteout.txt
# ../data/clean_data/W/War Horse.txt
# ../data/clean_data/W/Wild At Heart.txt
# ../data/clean_data/W/White Christmas.txt
# ../data/clean_data/W/War of the Worlds.txt
# ../data/clean_data/W/Walking Tall.txt
# ../data/clean_data/W/Whistleblower, The.txt
# ../data/clean_data/W/Watchmen.txt
# ../data/clean_data/W/Wolf of Wall Street, The.txt
# ../data/clean_data/W/Wild Things.txt
# ../data/clean_data/W/We Own the Night.txt
# ../data/clean_data/W/Wild Wild West.txt
# ../data/clean_data/W/Wild Hogs.txt
# ../data/clean_data/W/Witness.txt
# ../data/clean_data/W/Who's Your Daddy.txt
# ../data/clean_data/W/Wrestler, The.txt
# ../data/clean_data/W/Wanted.txt
# ../data/clean_data/W/White Jazz.txt
# ../data/clean_data/W/Wild Things Diamonds in the Rough.txt
# ../data/clean_data/W/While She Was Out.txt
# ../data/clean_data/W/Warm Springs.txt
# ../data/clean_data/W/Wild Bunch, The.txt
# ../data/clean_data/W/Willow.txt
# ../data/clean_data/W/When a Stranger Calls.txt
# ../data/clean_data/W/Way Back, The.txt
# ../data/clean_data/W/Walk to Remember, A.txt
# ../data/clean_data/Y/You've Got Mail.txt
# ../data/clean_data/Y/Yes Man.txt
# ../data/clean_data/Y/Youth in Revolt.txt
# ../data/clean_data/Y/Year One.txt
# ../data/clean_data/Y/You Can Count On Me.txt
# ../data/clean_data/P/Power of One, The.txt
# ../data/clean_data/P/Proposal, The.txt
# ../data/clean_data/P/Petulia.txt
# ../data/clean_data/P/Prom Night.txt
# ../data/clean_data/P/Program, The.txt
# ../data/clean_data/P/Peggy Sue Got Married.txt
# ../data/clean_data/P/Pirates of the Caribbean.txt
# ../data/clean_data/P/Perfect Creature.txt
# ../data/clean_data/P/Patriot, The.txt
# ../data/clean_data/P/Private Life of Sherlock Holmes, The.txt
# ../data/clean_data/P/Prophecy, The.txt
# ../data/clean_data/P/Precious.txt
# ../data/clean_data/P/Platoon.txt
# ../data/clean_data/P/Pi.txt
# ../data/clean_data/P/Platinum Blonde.txt
# ../data/clean_data/P/Pianist, The.txt
# ../data/clean_data/P/Pleasantville.txt
# ../data/clean_data/P/Papadopoulos & Sons.txt
# ../data/clean_data/P/Pacifier, The.txt
# ../data/clean_data/P/Pariah.txt
# ../data/clean_data/P/Panic Room.txt
# ../data/clean_data/P/Piano, The.txt
# ../data/clean_data/P/Producer, The.txt
# ../data/clean_data/P/Peeping Tom.txt
# ../data/clean_data/P/Punch-Drunk Love.txt
# ../data/clean_data/P/Pulp Fiction.txt
# ../data/clean_data/P/Phone Booth.txt
# ../data/clean_data/P/Pandorum.txt
# ../data/clean_data/P/Pineapple Express.txt
# ../data/clean_data/P/Prometheus.txt
# ../data/clean_data/P/Perfect World, A.txt
# ../data/clean_data/P/Planet of the Apes, The.txt
# ../data/clean_data/P/Predator.txt
# ../data/clean_data/P/Pretty Woman.txt
# ../data/clean_data/P/Pirates of the Caribbean Dead Man's Chest.txt
# ../data/clean_data/P/Perks of Being a Wallflower, The.txt
# ../data/clean_data/P/Purple Rain.txt
# ../data/clean_data/P/Psycho.txt
# ../data/clean_data/P/Pet Sematary.txt
# ../data/clean_data/P/Postman, The.txt
# ../data/clean_data/P/Point Break.txt
# ../data/clean_data/P/Pretty Woman (final script).txt
# ../data/clean_data/P/Pearl Harbor.txt
# ../data/clean_data/P/Princess Bride, The.txt
# ../data/clean_data/P/Philadelphia.txt
# ../data/clean_data/P/Public Enemies.txt
# ../data/clean_data/P/Pitch Black.txt
# ../data/clean_data/P/Pet Sematary II.txt
# ../data/clean_data/P/ParaNorman.txt
# ../data/clean_data/P/Pride and Prejudice.txt
# ../data/clean_data/P/Priest.txt
# ../data/clean_data/P/Paul.txt
# ../data/clean_data/B/Basic Instinct.txt
# ../data/clean_data/B/Being John Malkovich.txt
# ../data/clean_data/B/Bourne Identity, The.txt
# ../data/clean_data/B/Bad Dreams.txt
# ../data/clean_data/B/Boogie Nights.txt
# ../data/clean_data/B/Black Snake Moan.txt
# ../data/clean_data/B/Battle of Algiers, The.txt
# ../data/clean_data/B/Boondock Saints, The.txt
# ../data/clean_data/B/Blade II.txt
# ../data/clean_data/B/Bringing Out the Dead.txt
# ../data/clean_data/B/Boyhood.txt
# ../data/clean_data/B/Back-up Plan, The.txt
# ../data/clean_data/B/Birdman.txt
# ../data/clean_data/B/Body of Evidence.txt
# ../data/clean_data/B/Bounty Hunter, The.txt
# ../data/clean_data/B/Beasts of the Southern Wild.txt
# ../data/clean_data/B/Body Heat.txt
# ../data/clean_data/B/Big Fish.txt
# ../data/clean_data/B/Blue Valentine.txt
# ../data/clean_data/B/Braveheart.txt
# ../data/clean_data/B/Breakdown.txt
# ../data/clean_data/B/Babel.txt
# ../data/clean_data/B/Butterfly Effect, The.txt
# ../data/clean_data/B/Beginners.txt
# ../data/clean_data/B/Basic.txt
# ../data/clean_data/B/Bull Durham.txt
# ../data/clean_data/B/Bamboozled.txt
# ../data/clean_data/B/Blood Simple.txt
# ../data/clean_data/B/Blue Velvet.txt
# ../data/clean_data/B/Badlands.txt
# ../data/clean_data/B/Breaking Away.txt
# ../data/clean_data/B/Batman.txt
# ../data/clean_data/B/Brick.txt
# ../data/clean_data/B/Backdraft.txt
# ../data/clean_data/B/Bonnie and Clyde.txt
# ../data/clean_data/B/Bones.txt
# ../data/clean_data/B/Broken Arrow.txt
# ../data/clean_data/B/Bad Lieutenant.txt
# ../data/clean_data/B/Bound.txt
# ../data/clean_data/B/Bad Country.txt
# ../data/clean_data/B/Boondock Saints 2 All Saints Day.txt
# ../data/clean_data/B/Blast from the Past, The.txt
# ../data/clean_data/B/Basquiat.txt
# ../data/clean_data/B/Blood and Wine.txt
# ../data/clean_data/B/Breakfast Club, The.txt
# ../data/clean_data/B/Big White, The.txt
# ../data/clean_data/B/Bonfire of the Vanities.txt
# ../data/clean_data/B/Bachelor Party.txt
# ../data/clean_data/B/Blade Runner.txt
# ../data/clean_data/B/Blade Trinity.txt
# ../data/clean_data/B/Big Lebowski, The.txt
# ../data/clean_data/B/Blade.txt
# ../data/clean_data/B/Birthday Girl.txt
# ../data/clean_data/B/Bad Boys.txt
# ../data/clean_data/B/Batman 2.txt
# ../data/clean_data/B/Battle Los Angeles.txt
# ../data/clean_data/B/Barton Fink.txt
# ../data/clean_data/B/Blind Side, The.txt
# ../data/clean_data/B/Bottle Rocket.txt
# ../data/clean_data/B/Belle.txt
# ../data/clean_data/B/Beach, The.txt
# ../data/clean_data/B/Bourne Ultimatum, The.txt
# ../data/clean_data/B/Best Exotic Marigold Hotel, The.txt
# ../data/clean_data/B/Blow.txt
# ../data/clean_data/B/Battle of Shaker Heights, The.txt
# ../data/clean_data/B/Burlesque.txt
# ../data/clean_data/B/Broken Embraces.txt
# ../data/clean_data/B/Believer, The.txt
# ../data/clean_data/B/Bridesmaids.txt
# ../data/clean_data/B/Bad Santa.txt
# ../data/clean_data/B/Being Human.txt
# ../data/clean_data/B/Burning Annie.txt
# ../data/clean_data/B/Bachelor Party, The.txt
# ../data/clean_data/B/Buffy the Vampire Slayer.txt
# ../data/clean_data/B/Bling Ring, The.txt
# ../data/clean_data/B/Big Blue, The.txt
# ../data/clean_data/B/Bad Teacher.txt
# ../data/clean_data/B/Big.txt
# ../data/clean_data/B/Black Swan.txt
# ../data/clean_data/B/Big Eyes.txt
# ../data/clean_data/B/Bad Day at Black Rock.txt
# ../data/clean_data/B/Brothers Bloom, The.txt
# ../data/clean_data/B/Beavis and Butt-head Do America.txt
# ../data/clean_data/B/Beloved.txt
# ../data/clean_data/B/Bodies, Rest & Motion.txt
# ../data/clean_data/B/Brazil.txt
# ../data/clean_data/B/Being There.txt
# ../data/clean_data/B/Barry Lyndon.txt
# ../data/clean_data/B/Black Dahlia, The.txt
# ../data/clean_data/B/Birds, The.txt
# ../data/clean_data/B/Bean.txt
# ../data/clean_data/B/Black Rain.txt
# ../data/clean_data/B/Broadcast News.txt
# ../data/clean_data/B/Book of Eli, The.txt
# ../data/clean_data/B/Bruce Almighty.txt
# ../data/clean_data/B/Buried.txt
# ../data/clean_data/B/Burn After Reading.txt
# ../data/clean_data/B/Box, The.txt
# ../data/clean_data/B/Bodyguard.txt
# ../data/clean_data/L/Light Sleeper.txt
# ../data/clean_data/L/Living in Oblivion.txt
# ../data/clean_data/L/Little Athens.txt
# ../data/clean_data/L/Labor of Love.txt
# ../data/clean_data/L/Last Flight, The.txt
# ../data/clean_data/L/Lost Highway.txt
# ../data/clean_data/L/Les Tontons Flingueurs.txt
# ../data/clean_data/L/Leviathan.txt
# ../data/clean_data/L/Last of the Mohicans, The.txt
# ../data/clean_data/L/Les Miserables.txt
# ../data/clean_data/L/Life of David Gale, The.txt
# ../data/clean_data/L/Lone Star.txt
# ../data/clean_data/L/Lost in Translation.txt
# ../data/clean_data/L/Lincoln.txt
# ../data/clean_data/L/Lord of War.txt
# ../data/clean_data/L/Larry Crowne.txt
# ../data/clean_data/L/Lock, Stock and Two Smoking Barrels.txt
# ../data/clean_data/L/Love and Basketball.txt
# ../data/clean_data/L/Liar Liar.txt
# ../data/clean_data/L/Losers, The.txt
# ../data/clean_data/L/Last Boy Scout, The.txt
# ../data/clean_data/L/Legally Blonde.txt
# ../data/clean_data/L/Looper.txt
# ../data/clean_data/L/Last Chance Harvey.txt
# ../data/clean_data/L/Long Kiss Goodnight, The.txt
# ../data/clean_data/L/Last Station, The.txt
# ../data/clean_data/L/Lord of the Rings The Two Towers.txt
# ../data/clean_data/L/Lincoln Lawyer, The.txt
# ../data/clean_data/L/Life.txt
# ../data/clean_data/L/Lost in Space.txt
# ../data/clean_data/L/Limitless.txt
# ../data/clean_data/L/Ladykillers, The.txt
# ../data/clean_data/L/Lord of the Rings Return of the King.txt
# ../data/clean_data/L/Limey, The.txt
# ../data/clean_data/L/Last Samurai, The.txt
# ../data/clean_data/L/Land of the Dead.txt
# ../data/clean_data/L/L.A. Confidential.txt
# ../data/clean_data/L/Little Nicky.txt
# ../data/clean_data/L/Leaving Las Vegas.txt
# ../data/clean_data/L/Lake Placid.txt
# ../data/clean_data/L/Life As A House.txt
# ../data/clean_data/L/Logan's Run.txt
# ../data/clean_data/L/La La Land.txt
# ../data/clean_data/L/Legion.txt
# ../data/clean_data/L/Last Tango in Paris.txt
# ../data/clean_data/L/Lord of the Rings Fellowship of the Ring, The.txt
# ../data/clean_data/L/Life of Pi.txt
# ../data/clean_data/L/Le Diable par la Queue.txt
# ../data/clean_data/L/Law Abiding Citizen.txt
# ../data/clean_data/L/Lost Horizon.txt
# ../data/clean_data/L/Lord of Illusions.txt
# ../data/clean_data/J/Jason X.txt
# ../data/clean_data/J/Jimmy and Judy.txt
# ../data/clean_data/J/Jay and Silent Bob Strike Back.txt
# ../data/clean_data/J/Jaws.txt
# ../data/clean_data/J/Jaws 2.txt
# ../data/clean_data/J/Jeux Interdits.txt
# ../data/clean_data/J/Jacket, The.txt
# ../data/clean_data/J/Jennifer's Body.txt
# ../data/clean_data/J/Jurassic Park The Lost World.txt
# ../data/clean_data/J/Jurassic Park III.txt
# ../data/clean_data/J/Jennifer Eight.txt
# ../data/clean_data/J/JFK.txt
# ../data/clean_data/J/Jackie Brown.txt
# ../data/clean_data/J/Jacob's Ladder.txt
# ../data/clean_data/J/Jerry Maguire.txt
# ../data/clean_data/J/Jane Eyre.txt
# ../data/clean_data/J/Judge Dredd.txt
# ../data/clean_data/J/Jurassic Park.txt
# ../data/clean_data/J/Juno.txt
# ../data/clean_data/A/Airplane 2 The Sequel.txt
# ../data/clean_data/A/American Beauty.txt
# ../data/clean_data/A/Arcade.txt
# ../data/clean_data/A/Absolute Power.txt
# ../data/clean_data/A/Arthur.txt
# ../data/clean_data/A/Angels & Demons.txt
# ../data/clean_data/A/American Graffiti.txt
# ../data/clean_data/A/Air Force One.txt
# ../data/clean_data/A/Avengers, The.txt
# ../data/clean_data/A/Apt Pupil.txt
# ../data/clean_data/A/American Pie.txt
# ../data/clean_data/A/Alien vs. Predator.txt
# ../data/clean_data/A/Antitrust.txt
# ../data/clean_data/A/Almost Famous.txt
# ../data/clean_data/A/Alien 3.txt
# ../data/clean_data/A/American Psycho.txt
# ../data/clean_data/A/Army of Darkness.txt
# ../data/clean_data/A/A Serious Man.txt
# ../data/clean_data/A/Amour.txt
# ../data/clean_data/A/Anniversary Party, The.txt
# ../data/clean_data/A/Antz.txt
# ../data/clean_data/A/Anonymous.txt
# ../data/clean_data/A/Avengers, The (2012).txt
# ../data/clean_data/A/American Gangster.txt
# ../data/clean_data/A/After.Life.txt
# ../data/clean_data/A/Awakenings.txt
# ../data/clean_data/A/Aliens.txt
# ../data/clean_data/A/A Few Good Men.txt
# ../data/clean_data/A/Arctic Blue.txt
# ../data/clean_data/A/All About Eve.txt
# ../data/clean_data/A/Arbitrage.txt
# ../data/clean_data/A/Analyze This.txt
# ../data/clean_data/A/American, The.txt
# ../data/clean_data/A/After School Special.txt
# ../data/clean_data/A/Authors Anonymous.txt
# ../data/clean_data/A/American History X.txt
# ../data/clean_data/A/Alone in the Dark.txt
# ../data/clean_data/A/American Werewolf in London.txt
# ../data/clean_data/A/Avatar.txt
# ../data/clean_data/A/Apartment, The.txt
# ../data/clean_data/A/American Hustle.txt
# ../data/clean_data/A/Analyze That.txt
# ../data/clean_data/A/All About Steve.txt
# ../data/clean_data/A/American Sniper.txt
# ../data/clean_data/A/Anastasia.txt
# ../data/clean_data/A/An Education.txt
# ../data/clean_data/A/Austin Powers - International Man of Mystery.txt
# ../data/clean_data/A/Austin Powers - The Spy Who Shagged Me.txt
# ../data/clean_data/A/American Splendor.txt
# ../data/clean_data/A/Above the Law.txt
# ../data/clean_data/A/All the King's Men.txt
# ../data/clean_data/A/Airplane.txt
# ../data/clean_data/A/Autumn in New York.txt
# ../data/clean_data/A/A Most Violent Year.txt
# ../data/clean_data/A/Apocalypse Now.txt
# ../data/clean_data/A/April Fool's Day.txt
# ../data/clean_data/A/Amityville Asylum, The.txt
# ../data/clean_data/A/Avventura, L' (The Adventure).txt
# ../data/clean_data/A/Adventures of Buckaroo Banzai Across the Eighth Dimension, The.txt
# ../data/clean_data/A/Agnes of God.txt
# ../data/clean_data/A/Amadeus.txt
# ../data/clean_data/A/Ali.txt
# ../data/clean_data/A/Assignment, The.txt
# ../data/clean_data/A/Arsenic and Old Lace.txt
# ../data/clean_data/A/Angel Eyes.txt
# ../data/clean_data/A/Amelia.txt
# ../data/clean_data/A/All the President's Men.txt
# ../data/clean_data/A/Abyss, The.txt
# ../data/clean_data/A/Alien.txt
# ../data/clean_data/A/August Osage County.txt
# ../data/clean_data/A/Adjustment Bureau, The.txt
# ../data/clean_data/A/Anna Karenina.txt
# ../data/clean_data/A/Argo.txt
# ../data/clean_data/A/American Shaolin King of Kickboxers II.txt
# ../data/clean_data/A/American President, The.txt
# ../data/clean_data/A/American Madness.txt
# ../data/clean_data/A/Affliction.txt
# ../data/clean_data/A/Addams Family, The.txt
# ../data/clean_data/A/Assassins.txt
# ../data/clean_data/A/Annie Hall.txt
# ../data/clean_data/A/As Good As It Gets.txt
# ../data/clean_data/A/Alien Resurrection.txt
# ../data/clean_data/A/Alien Nation.txt
# ../data/clean_data/A/Adaptation.txt
# ../data/clean_data/C/Crash.txt
# ../data/clean_data/C/Coriolanus.txt
# ../data/clean_data/C/Colombiana.txt
# ../data/clean_data/C/Croods, The.txt
# ../data/clean_data/C/Cherry Falls.txt
# ../data/clean_data/C/Crouching Tiger, Hidden Dragon.txt
# ../data/clean_data/C/Cooler, The.txt
# ../data/clean_data/C/Crow, The.txt
# ../data/clean_data/C/Citizen Kane.txt
# ../data/clean_data/C/Cowboys & Aliens.txt
# ../data/clean_data/C/Cecil B. Demented.txt
# ../data/clean_data/C/Cedar Rapids.txt
# ../data/clean_data/C/Chaos.txt
# ../data/clean_data/C/Collateral Damage.txt
# ../data/clean_data/C/Candle to Water.txt
# ../data/clean_data/C/Crazylove.txt
# ../data/clean_data/C/Custody.txt
# ../data/clean_data/C/Carrie.txt
# ../data/clean_data/C/Charlie's Angels.txt
# ../data/clean_data/C/Crazy, Stupid, Love.txt
# ../data/clean_data/C/Confidence.txt
# ../data/clean_data/C/Code of Silence.txt
# ../data/clean_data/C/Croupier.txt
# ../data/clean_data/C/Creation.txt
# ../data/clean_data/C/Commando.txt
# ../data/clean_data/C/Cobb.txt
# ../data/clean_data/C/City of Joy.txt
# ../data/clean_data/C/Constantine.txt
# ../data/clean_data/C/Copycat.txt
# ../data/clean_data/C/Cellular.txt
# ../data/clean_data/C/Conan the Barbarian.txt
# ../data/clean_data/C/Crying Game.txt
# ../data/clean_data/C/Coraline.txt
# ../data/clean_data/C/Christ Complex.txt
# ../data/clean_data/C/Chasing Sleep.txt
# ../data/clean_data/C/Clash of the Titans.txt
# ../data/clean_data/C/Cable Guy.txt
# ../data/clean_data/C/Clerks.txt
# ../data/clean_data/C/Color of Night.txt
# ../data/clean_data/C/Crow Salvation, The.txt
# ../data/clean_data/C/Chinatown.txt
# ../data/clean_data/C/Cliffhanger.txt
# ../data/clean_data/C/Crow City of Angels, The.txt
# ../data/clean_data/C/Catch Me If You Can.txt
# ../data/clean_data/C/Cruel Intentions.txt
# ../data/clean_data/C/Curious Case of Benjamin Button, The.txt
# ../data/clean_data/C/Charade.txt
# ../data/clean_data/C/Crime Spree.txt
# ../data/clean_data/C/Cradle 2 the Grave.txt
# ../data/clean_data/C/Celeste & Jesse Forever.txt
# ../data/clean_data/C/Cider House Rules, The.txt
# ../data/clean_data/C/Cast Away.txt
# ../data/clean_data/C/Cars 2.txt
# ../data/clean_data/C/Chronicle.txt
# ../data/clean_data/C/Cell, The.txt
# ../data/clean_data/C/Cincinnati Kid, The.txt
# ../data/clean_data/C/Cold Mountain.txt
# ../data/clean_data/C/Case 39.txt
# ../data/clean_data/C/Capote.txt
# ../data/clean_data/C/Casino.txt
# ../data/clean_data/C/Chasing Amy.txt
# ../data/clean_data/C/Crank.txt
# ../data/clean_data/C/Confessions of a Dangerous Mind.txt
# ../data/clean_data/C/Cirque du Freak The Vampire's Assistant.txt
# ../data/clean_data/C/Chronicles of Narnia The Lion, the Witch and the Wardrobe.txt
# ../data/clean_data/C/Change-Up, The.txt
# ../data/clean_data/C/Changeling.txt
# ../data/clean_data/C/Cinema Paradiso.txt
# ../data/clean_data/T/Taxi Driver.txt
# ../data/clean_data/T/Terminator.txt
# ../data/clean_data/T/Timber Falls.txt
# ../data/clean_data/T/Titanic.txt
# ../data/clean_data/T/Tall in the Saddle.txt
# ../data/clean_data/T/To Sleep with Anger.txt
# ../data/clean_data/T/Tombstone.txt
# ../data/clean_data/T/Talented Mr. Ripley, The.txt
# ../data/clean_data/T/Total Recall.txt
# ../data/clean_data/T/Thelma & Louise.txt
# ../data/clean_data/T/TRON.txt
# ../data/clean_data/T/Three Kings (Spoils of War).txt
# ../data/clean_data/T/Terminator Salvation.txt
# ../data/clean_data/T/Ticker.txt
# ../data/clean_data/T/Time Machine, The.txt
# ../data/clean_data/T/Two For The Money.txt
# ../data/clean_data/T/True Lies.txt
# ../data/clean_data/T/Three Musketeers, The.txt
# ../data/clean_data/T/Tomorrow Never Dies.txt
# ../data/clean_data/T/Three Kings.txt
# ../data/clean_data/T/Twin Peaks.txt
# ../data/clean_data/T/Twilight.txt
# ../data/clean_data/T/Truman Show, The.txt
# ../data/clean_data/T/Tourist, The.txt
# ../data/clean_data/T/Taking of Pelham One Two Three, The.txt
# ../data/clean_data/T/Trainspotting.txt
# ../data/clean_data/T/Thunderheart.txt
# ../data/clean_data/T/Ted.txt
# ../data/clean_data/T/Toy Story.txt
# ../data/clean_data/T/TRON Legacy.txt
# ../data/clean_data/T/Thing, The.txt
# ../data/clean_data/T/Thor.txt
# ../data/clean_data/T/Tamara Drewe.txt
# ../data/clean_data/T/Thirteen Days.txt
# ../data/clean_data/T/Tin Cup.txt
# ../data/clean_data/T/Tremors.txt
# ../data/clean_data/T/Terminator 2 Judgement Day.txt
# ../data/clean_data/T/Twins.txt
# ../data/clean_data/T/Thunderbirds.txt
# ../data/clean_data/T/The Rage Carrie 2.txt
# ../data/clean_data/T/Top Gun.txt
# ../data/clean_data/T/Taking Sides.txt
# ../data/clean_data/T/Three Men and a Baby.txt
# ../data/clean_data/T/TMNT.txt
# ../data/clean_data/T/Traffic.txt
# ../data/clean_data/T/There's Something About Mary.txt
# ../data/clean_data/T/Twilight New Moon.txt
# ../data/clean_data/T/Tristan and Isolde.txt
# ../data/clean_data/T/Transformers The Movie.txt
# ../data/clean_data/T/Tin Men.txt
# ../data/clean_data/T/Take Shelter.txt
# ../data/clean_data/T/Tropic Thunder.txt
# ../data/clean_data/T/This is 40.txt
# ../data/clean_data/T/This Boy's Life.txt
# ../data/clean_data/T/Tinker Tailor Soldier Spy.txt
# ../data/clean_data/T/Taking Lives.txt
# ../data/clean_data/V/Valkyrie.txt
# ../data/clean_data/V/Virtuosity.txt
# ../data/clean_data/V/Visitor, The.txt
# ../data/clean_data/V/Very Bad Things.txt
# ../data/clean_data/V/Verdict, The.txt
# ../data/clean_data/V/Vanilla Sky.txt
# ../data/clean_data/V/V for Vendetta.txt

# %% [markdown]
# # Create vocab file

# %% [raw]
# tr -sc "[A-Z][a-z][0-9]'" '[\012*]' < all_dialogs.txt | tr '[A-Z]' '[a-z]' | sort | uniq -c | sort -nr > unigram_count.txt

# %%
words = []
rejects = []
for line in open('../res/unigram_count.txt'):
    c, w = line.strip().split()
    if w.isalpha():
        words.append(w)
    else:
        rejects.append(w)
with open('../res/vocab.txt', 'w') as f:
    f.write('\n'.join(words))

with open('../res/rejects.txt', 'w') as f:
    f.write('\n'.join(rejects))

# %% [raw]
# from nltk.stem.porter import *
# stemmer = PorterStemmer()
# stems = []
# for line in open('../res/vocab.txt'):
#     word = line.strip()
#     try:
#         stem = stemmer.stem(word)
#         stems.append(stem)
#     except:
#         print word
#
# with open('../res/stem_words.txt', 'w') as f:
#     f.write('\n'.join(list(set(stems))))

# %% [raw]
# from tqdm import tqdm
# stems = []
# reject_list = []
# i = 0
# printable = set(string.printable)
# func = lambda s: filter(lambda x: x in printable, s)
# for line in tqdm(open('../res/embed_vocab.txt')):
#     word = line.strip()
#     word = func(word)
#     try:
#         stem = stemmer.stem(word)
#         stems.append(str(stem) + ' ' + str(i))
#     except:
#         reject_list.append(word)
#     i += 1
# with open('../res/embed_stem_words.txt', 'w') as f:
#     f.write('\n'.join(list(set(stems))))

# %% [markdown]
# # Don't stem chars cos of chat problem

# %%
stems = set(line.strip() for line in open('../res/embed_vocab.txt'))
word_to_ind = {s.strip():int(i) for i, s in enumerate(open('../res/embed_vocab.txt'))}
our_stem_words = set(line.strip() for line in open('../res/vocab.txt'))

# Find the intersection between the two
new_stems = stems & our_stem_words

# Find the missing words

# %%
new_stems = list(new_stems)
len(new_stems)
# Out:
# 66532

# %%
inds = [word_to_ind[w] for w in new_stems]
new_stems = ['_PAD', '_GO', '_EOS', '_UNK'] + new_stems
with open('../res/filtered_vocab.txt', 'w') as f:
    f.write('\n'.join(new_stems))

# %%
import linecache
from tqdm import tqdm
embed_dims = 200
embed_file = '../data/glove.twitter.27B/glove.twitter.27B.' + str(embed_dims) + 'd.txt'
mat = []

# Add special words to embedding
special_words = ['_PAD', '_GO', '_EOS', '_UNK']
for i in range(len(special_words)):
    vector = [i]*embed_dims #size of embedding
    mat.append(vector)
    
for i in tqdm(inds):
    line = linecache.getline(embed_file, i)
    parts = line.strip().split()
    word = parts[0]
    vector = [float(f) for f in parts[1:]]
    mat.append(vector)
# Out:
# 100%|██████████| 66532/66532 [00:38<00:00, 1717.61it/s]

# %%
import numpy as np
embed = np.array(mat)
import cPickle as pickle
pickle.dump(embed, open('../res/embed_weights.pkl', 'w'))

# %%
embed.shape
# Out:
# (66536, 200)

# %%
from nltk.stem.porter import *
from tqdm import tqdm
stemmer = PorterStemmer()
nl = []
rejects = []
for line in tqdm(open('../res/all_dialogs.txt')):
    line = line.strip()
    s = ''
    for w in line.split():
        if not w.isalpha():
            w = "DIGIT"
#         else:
#             try:
#                 w = stemmer.stem(w)
#             except:
#                 rejects.append(w)
        s += w + ' '
    nl.append(s)

with open('../res/filtered_dialogs.txt', 'w') as f:
    f.write('\n'.join(nl))
# Out:
# 747091it [00:04, 163573.10it/s]

# %%
lines = open('../res/filtered_dialogs.txt').readlines()

# %% [markdown]
# # Create train and validation files

# %%
even = lines[0::2]
odd = lines[1::2]

val_ind = int(len(even)*0.70)

test_ques = even[:-val_ind]
test_ans = odd[:-val_ind]
train_ques = even[-val_ind:]
train_ans = odd[-val_ind:]
with open('../res/train_ques.txt', 'w') as f:
    f.write(''.join(train_ques))
with open('../res/train_ans.txt', 'w') as f:
    f.write(''.join(train_ans))
with open('../res/val_ques.txt', 'w') as f:
    f.write(''.join(test_ques))
with open('../res/val_ans.txt', 'w') as f:
    f.write(''.join(test_ans))

# %%
val_ind = int(len(even)*0.70)

test_ques = even[:-val_ind]
test_ans = odd[:-val_ind]
train_ques = even[-val_ind:]
train_ans = odd[-val_ind:]

# %%
len(train_ques)
# Out:
# 261482
