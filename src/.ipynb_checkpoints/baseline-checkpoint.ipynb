# %%
import tensorflow as tf
from converse import *

# %% [raw]
# # Size dimensions
# # K = size of the character embedding
# # H = size of the hidden state
# # D = dimensions of the word embedding

# %%
config = {
        'test':False,
        'learning_rate':0.05,
        'batch_size':2,
        'hidden_size':256,
        'num_layers':1,
        'use_lstm':True,#Else use GRU
        }

# %% [markdown]
# # Training

# %%
data = prepare() # Prepare data for training and validation
config['test'] = False
with tf.Session() as sess:
    model = create_model(sess, conf=config)
    model = train(sess, model, data)
# Out:
# Tokenizing data in ../res/train_ans.txt
#   tokenizing line 100000
#   tokenizing line 200000
#   tokenizing line 300000
# Tokenizing data in ../res/train_ques.txt
#   tokenizing line 100000
#   tokenizing line 200000
#   tokenizing line 300000
# Tokenizing data in ../res/val_ans.txt
# Tokenizing data in ../res/val_ques.txt
#   reading data line 100000
#   reading data line 200000
#   reading data line 300000
# Creating 256  of 1 layers
# 66533 256
# Created model with fresh parameters.
# Testing the model
# global step 200 learning rate 0.0500 step-time 0.09 perplexity 48.14
#   eval: bucket 0 perplexity 19.71
#   eval: bucket 1 perplexity 10.91
#   eval: bucket 2 perplexity 31.62
#   eval: bucket 3 perplexity 12.73
# Testing the model
# global step 400 learning rate 0.0500 step-time 0.07 perplexity 13.34
#   eval: bucket 0 perplexity 5.08
#   eval: bucket 1 perplexity 37.32
#   eval: bucket 2 perplexity 14.46
#   eval: bucket 3 perplexity 81.45
# Testing the model
# global step 600 learning rate 0.0500 step-time 0.07 perplexity 10.54
#   eval: bucket 0 perplexity 6.24
#   eval: bucket 1 perplexity 10.57
#   eval: bucket 2 perplexity 15.49
#   eval: bucket 3 perplexity 6.15
# Testing the model
# global step 800 learning rate 0.0500 step-time 0.07 perplexity 9.05
#   eval: bucket 0 perplexity 2.81
#   eval: bucket 1 perplexity 6.33
#   eval: bucket 2 perplexity 5.80
#   eval: bucket 3 perplexity 19.70
# Testing the model
# global step 1000 learning rate 0.0500 step-time 0.07 perplexity 8.47
#   eval: bucket 0 perplexity 8.81
#   eval: bucket 1 perplexity 6.25
#   eval: bucket 2 perplexity 9.93
#   eval: bucket 3 perplexity 4.17
# Testing the model
# global step 1200 learning rate 0.0500 step-time 0.07 perplexity 8.45
#   eval: bucket 0 perplexity 8.35
#   eval: bucket 1 perplexity 24.88
#   eval: bucket 2 perplexity 11.65
#   eval: bucket 3 perplexity 6.53
# Testing the model
# global step 1400 learning rate 0.0500 step-time 0.07 perplexity 8.44
#   eval: bucket 0 perplexity 2.94
#   eval: bucket 1 perplexity 8.04
#   eval: bucket 2 perplexity 14.67
#   eval: bucket 3 perplexity 18.51
# Testing the model
# global step 1600 learning rate 0.0500 step-time 0.07 perplexity 7.80
#   eval: bucket 0 perplexity 3.08
#   eval: bucket 1 perplexity 10.86
#   eval: bucket 2 perplexity 5.57
#   eval: bucket 3 perplexity 30.04
# Testing the model
# global step 1800 learning rate 0.0500 step-time 0.07 perplexity 8.03
#   eval: bucket 0 perplexity 4.72
#   eval: bucket 1 perplexity 6.40
#   eval: bucket 2 perplexity 8.32
#   eval: bucket 3 perplexity 4.76
# Testing the model
# global step 2000 learning rate 0.0500 step-time 0.07 perplexity 7.44
#   eval: bucket 0 perplexity 5.61
#   eval: bucket 1 perplexity 5.72
#   eval: bucket 2 perplexity 3.05
#   eval: bucket 3 perplexity 5.97
# Testing the model
# global step 2200 learning rate 0.0500 step-time 0.07 perplexity 7.34
#   eval: bucket 0 perplexity 1.59
#   eval: bucket 1 perplexity 3.70
#   eval: bucket 2 perplexity 8.93
#   eval: bucket 3 perplexity 15.46
# Testing the model
# global step 2400 learning rate 0.0500 step-time 0.07 perplexity 7.07
#   eval: bucket 0 perplexity 4.38
#   eval: bucket 1 perplexity 5.52
#   eval: bucket 2 perplexity 10.27
#   eval: bucket 3 perplexity 4.20
# Testing the model
# global step 2600 learning rate 0.0500 step-time 0.08 perplexity 7.49
#   eval: bucket 0 perplexity 30.22
#   eval: bucket 1 perplexity 18.86
#   eval: bucket 2 perplexity 12.10
#   eval: bucket 3 perplexity 7.81
# Testing the model
# global step 2800 learning rate 0.0495 step-time 0.07 perplexity 7.17
#   eval: bucket 0 perplexity 6.27
#   eval: bucket 1 perplexity 4.91
#   eval: bucket 2 perplexity 6.71
#   eval: bucket 3 perplexity 12.57
# Testing the model
# global step 3000 learning rate 0.0495 step-time 0.06 perplexity 7.19
#   eval: bucket 0 perplexity 2.68
#   eval: bucket 1 perplexity 11.24
#   eval: bucket 2 perplexity 4.44
#   eval: bucket 3 perplexity 6.83
# Testing the model
# global step 3200 learning rate 0.0495 step-time 0.08 perplexity 6.33
#   eval: bucket 0 perplexity 5.41
#   eval: bucket 1 perplexity 8.27
#   eval: bucket 2 perplexity 14.31
#   eval: bucket 3 perplexity 7.08
# Testing the model
# global step 3400 learning rate 0.0495 step-time 0.07 perplexity 7.51
#   eval: bucket 0 perplexity 3.77
#   eval: bucket 1 perplexity 8.65
#   eval: bucket 2 perplexity 4.23
#   eval: bucket 3 perplexity 4.82
# Testing the model
# global step 3600 learning rate 0.0490 step-time 0.07 perplexity 7.12
#   eval: bucket 0 perplexity 3.65
#   eval: bucket 1 perplexity 9.05
#   eval: bucket 2 perplexity 5.73
#   eval: bucket 3 perplexity 5.78
# Testing the model
# global step 3800 learning rate 0.0490 step-time 0.07 perplexity 7.00
#   eval: bucket 0 perplexity 32.27
#   eval: bucket 1 perplexity 4.33
#   eval: bucket 2 perplexity 8.34
#   eval: bucket 3 perplexity 6.55
# Testing the model
# global step 4000 learning rate 0.0490 step-time 0.07 perplexity 6.53
#   eval: bucket 0 perplexity 1.64
#   eval: bucket 1 perplexity 7.72
#   eval: bucket 2 perplexity 26.96
#   eval: bucket 3 perplexity 16.48
# Testing the model
# global step 4200 learning rate 0.0490 step-time 0.07 perplexity 6.79
#   eval: bucket 0 perplexity 2.64
#   eval: bucket 1 perplexity 5.78
#   eval: bucket 2 perplexity 5.22
#   eval: bucket 3 perplexity 3.02
# Testing the model
# global step 4400 learning rate 0.0490 step-time 0.07 perplexity 6.31
#   eval: bucket 0 perplexity 2.14
#   eval: bucket 1 perplexity 3.59
#   eval: bucket 2 perplexity 19.88
#   eval: bucket 3 perplexity 22.74
# Testing the model
# global step 4600 learning rate 0.0490 step-time 0.07 perplexity 6.97
#   eval: bucket 0 perplexity 3.45
#   eval: bucket 1 perplexity 6.16
#   eval: bucket 2 perplexity 5.14
#   eval: bucket 3 perplexity 4.27
# Testing the model
# global step 4800 learning rate 0.0485 step-time 0.07 perplexity 6.43
#   eval: bucket 0 perplexity 1.78
#   eval: bucket 1 perplexity 3.27
#   eval: bucket 2 perplexity 3.60
#   eval: bucket 3 perplexity 5.03
# Testing the model
# global step 5000 learning rate 0.0485 step-time 0.07 perplexity 6.84
#   eval: bucket 0 perplexity 3.31
#   eval: bucket 1 perplexity 12.55
#   eval: bucket 2 perplexity 8.24
#   eval: bucket 3 perplexity 10.79
# Testing the model
# global step 5200 learning rate 0.0485 step-time 0.07 perplexity 6.26
#   eval: bucket 0 perplexity 1.51
#   eval: bucket 1 perplexity 2.29
#   eval: bucket 2 perplexity 7.95
#   eval: bucket 3 perplexity 6.59
# Testing the model
# global step 5400 learning rate 0.0485 step-time 0.07 perplexity 6.34
#   eval: bucket 0 perplexity 8.28
#   eval: bucket 1 perplexity 8.13
#   eval: bucket 2 perplexity 6.10
#   eval: bucket 3 perplexity 3.18
# Testing the model
# global step 5600 learning rate 0.0485 step-time 0.07 perplexity 6.45
#   eval: bucket 0 perplexity 5.34
#   eval: bucket 1 perplexity 5.30
#   eval: bucket 2 perplexity 4.98
#   eval: bucket 3 perplexity 17.94
# Testing the model
# global step 5800 learning rate 0.0485 step-time 0.07 perplexity 6.58
#   eval: bucket 0 perplexity 3.21
#   eval: bucket 1 perplexity 7.64
#   eval: bucket 2 perplexity 5.78
#   eval: bucket 3 perplexity 5.95
# Testing the model
# global step 6000 learning rate 0.0480 step-time 0.06 perplexity 6.05
#   eval: bucket 0 perplexity 3.57
#   eval: bucket 1 perplexity 9.70
#   eval: bucket 2 perplexity 3.66
#   eval: bucket 3 perplexity 5.52
# Testing the model
# global step 6200 learning rate 0.0480 step-time 0.07 perplexity 6.44
#   eval: bucket 0 perplexity 3.19
#   eval: bucket 1 perplexity 2.31
#   eval: bucket 2 perplexity 6.84
#   eval: bucket 3 perplexity 4.07
# Testing the model
# global step 6400 learning rate 0.0480 step-time 0.07 perplexity 6.55
#   eval: bucket 0 perplexity 6.32
#   eval: bucket 1 perplexity 5.86
#   eval: bucket 2 perplexity 6.44
#   eval: bucket 3 perplexity 6.89
# Testing the model
# global step 6600 learning rate 0.0480 step-time 0.07 perplexity 6.56
#   eval: bucket 0 perplexity 3.22
#   eval: bucket 1 perplexity 3.25
#   eval: bucket 2 perplexity 4.13
#   eval: bucket 3 perplexity 6.70
# Testing the model
# global step 6800 learning rate 0.0475 step-time 0.07 perplexity 6.47
#   eval: bucket 0 perplexity 2.10
#   eval: bucket 1 perplexity 3.42
#   eval: bucket 2 perplexity 2.20
#   eval: bucket 3 perplexity 4.25
# Testing the model
# global step 7000 learning rate 0.0475 step-time 0.07 perplexity 6.46
#   eval: bucket 0 perplexity 6.56
#   eval: bucket 1 perplexity 2.46
#   eval: bucket 2 perplexity 3.46
#   eval: bucket 3 perplexity 9.64
# Testing the model
# global step 7200 learning rate 0.0475 step-time 0.07 perplexity 6.35
#   eval: bucket 0 perplexity 12.71
#   eval: bucket 1 perplexity 12.08
#   eval: bucket 2 perplexity 2.96
#   eval: bucket 3 perplexity 7.94
# Testing the model
# global step 7400 learning rate 0.0475 step-time 0.07 perplexity 5.74
#   eval: bucket 0 perplexity 5.82
#   eval: bucket 1 perplexity 2.75
#   eval: bucket 2 perplexity 10.84
#   eval: bucket 3 perplexity 3.71
# Testing the model
# global step 7600 learning rate 0.0475 step-time 0.06 perplexity 6.57
#   eval: bucket 0 perplexity 3.46
#   eval: bucket 1 perplexity 4.89
#   eval: bucket 2 perplexity 1.91
#   eval: bucket 3 perplexity 2.87
# Testing the model
# global step 7800 learning rate 0.0471 step-time 0.07 perplexity 6.45
#   eval: bucket 0 perplexity 5.55
#   eval: bucket 1 perplexity 2.56
#   eval: bucket 2 perplexity 6.96
#   eval: bucket 3 perplexity 9.53
# Testing the model
# global step 8000 learning rate 0.0471 step-time 0.07 perplexity 5.83
#   eval: bucket 0 perplexity 6.15
#   eval: bucket 1 perplexity 5.54
#   eval: bucket 2 perplexity 5.36
#   eval: bucket 3 perplexity 9.00
# Testing the model
# global step 8200 learning rate 0.0471 step-time 0.07 perplexity 6.20
#   eval: bucket 0 perplexity 1.97
#   eval: bucket 1 perplexity 5.19
#   eval: bucket 2 perplexity 4.11
#   eval: bucket 3 perplexity 9.71
# Testing the model
# global step 8400 learning rate 0.0471 step-time 0.07 perplexity 6.12
#   eval: bucket 0 perplexity 9.25
#   eval: bucket 1 perplexity 2.36
#   eval: bucket 2 perplexity 5.03
#   eval: bucket 3 perplexity 4.95
# Testing the model
# global step 8600 learning rate 0.0471 step-time 0.07 perplexity 6.02
#   eval: bucket 0 perplexity 1.89
#   eval: bucket 1 perplexity 4.30
#   eval: bucket 2 perplexity 9.45
#   eval: bucket 3 perplexity 3.19
# Testing the model
# global step 8800 learning rate 0.0471 step-time 0.07 perplexity 5.86
#   eval: bucket 0 perplexity 9.05
#   eval: bucket 1 perplexity 3.68
#   eval: bucket 2 perplexity 4.82
#   eval: bucket 3 perplexity 6.23
# Testing the model
# global step 9000 learning rate 0.0471 step-time 0.07 perplexity 6.33
#   eval: bucket 0 perplexity 4.49
#   eval: bucket 1 perplexity 5.44
#   eval: bucket 2 perplexity 26.79
#   eval: bucket 3 perplexity 21.73
# Testing the model
# global step 9200 learning rate 0.0466 step-time 0.07 perplexity 6.40
#   eval: bucket 0 perplexity 6.05
#   eval: bucket 1 perplexity 60.81
#   eval: bucket 2 perplexity 6.04
#   eval: bucket 3 perplexity 5.68
# Testing the model
# global step 9400 learning rate 0.0461 step-time 0.07 perplexity 6.01
#   eval: bucket 0 perplexity 15.49
#   eval: bucket 1 perplexity 2.57
#   eval: bucket 2 perplexity 5.67
#   eval: bucket 3 perplexity 2.13
# Testing the model
# global step 9600 learning rate 0.0461 step-time 0.07 perplexity 6.51
#   eval: bucket 0 perplexity 1.60
#   eval: bucket 1 perplexity 6.46
#   eval: bucket 2 perplexity 4.04
#   eval: bucket 3 perplexity 3.05
# Testing the model
# global step 9800 learning rate 0.0457 step-time 0.07 perplexity 6.14
#   eval: bucket 0 perplexity 4.36
#   eval: bucket 1 perplexity 3.82
#   eval: bucket 2 perplexity 5.32
#   eval: bucket 3 perplexity 6.05
# Testing the model
# global step 10000 learning rate 0.0457 step-time 0.07 perplexity 5.82
#   eval: bucket 0 perplexity 2.97
#   eval: bucket 1 perplexity 1.88
#   eval: bucket 2 perplexity 5.51
#   eval: bucket 3 perplexity 8.70
# Testing the model
# global step 10200 learning rate 0.0457 step-time 0.07 perplexity 6.38
#   eval: bucket 0 perplexity 2.78
#   eval: bucket 1 perplexity 36.20
#   eval: bucket 2 perplexity 9.59
#   eval: bucket 3 perplexity 4.75
# Testing the model
# global step 10400 learning rate 0.0457 step-time 0.07 perplexity 5.90
#   eval: bucket 0 perplexity 2.37
#   eval: bucket 1 perplexity 7.69
#   eval: bucket 2 perplexity 3.12
#   eval: bucket 3 perplexity 5.66
# Testing the model
# global step 10600 learning rate 0.0457 step-time 0.07 perplexity 5.57
#   eval: bucket 0 perplexity 11.64
#   eval: bucket 1 perplexity 5.35
#   eval: bucket 2 perplexity 7.82
#   eval: bucket 3 perplexity 15.69
# Testing the model
# global step 10800 learning rate 0.0457 step-time 0.07 perplexity 5.96
#   eval: bucket 0 perplexity 2.83
#   eval: bucket 1 perplexity 2.63
#   eval: bucket 2 perplexity 5.90
#   eval: bucket 3 perplexity 7.36
# Testing the model
# global step 11000 learning rate 0.0457 step-time 0.07 perplexity 6.13
#   eval: bucket 0 perplexity 9.30
#   eval: bucket 1 perplexity 5.43
#   eval: bucket 2 perplexity 7.95
#   eval: bucket 3 perplexity 5.43
# Testing the model
# global step 11200 learning rate 0.0452 step-time 0.07 perplexity 5.58
#   eval: bucket 0 perplexity 2.01
#   eval: bucket 1 perplexity 5.57
#   eval: bucket 2 perplexity 9.34
#   eval: bucket 3 perplexity 4.94
# Testing the model
# global step 11400 learning rate 0.0452 step-time 0.07 perplexity 6.15
#   eval: bucket 0 perplexity 10.46
#   eval: bucket 1 perplexity 2.08
#   eval: bucket 2 perplexity 2.92
#   eval: bucket 3 perplexity 3.17
# Testing the model
# global step 11600 learning rate 0.0448 step-time 0.07 perplexity 5.90
#   eval: bucket 0 perplexity 3.69
#   eval: bucket 1 perplexity 2.64
#   eval: bucket 2 perplexity 2.91
#   eval: bucket 3 perplexity 2.50
# Testing the model
# global step 11800 learning rate 0.0448 step-time 0.07 perplexity 6.10
#   eval: bucket 0 perplexity 3.36
#   eval: bucket 1 perplexity 16.81
#   eval: bucket 2 perplexity 4.54
#   eval: bucket 3 perplexity 6.85
# Testing the model
# global step 12000 learning rate 0.0448 step-time 0.07 perplexity 5.94
#   eval: bucket 0 perplexity 4.23
#   eval: bucket 1 perplexity 2.33
#   eval: bucket 2 perplexity 7.77
#   eval: bucket 3 perplexity 4.49
# Testing the model
# global step 12200 learning rate 0.0448 step-time 0.07 perplexity 6.20
#   eval: bucket 0 perplexity 6.95
#   eval: bucket 1 perplexity 4.44
#   eval: bucket 2 perplexity 2.42
#   eval: bucket 3 perplexity 3.85
# Testing the model
# global step 12400 learning rate 0.0443 step-time 0.07 perplexity 6.15
#   eval: bucket 0 perplexity 2.98
#   eval: bucket 1 perplexity 2.39
#   eval: bucket 2 perplexity 2.75
#   eval: bucket 3 perplexity 18.33
# Testing the model
# global step 12600 learning rate 0.0443 step-time 0.07 perplexity 5.88
#   eval: bucket 0 perplexity 3.00
#   eval: bucket 1 perplexity 2.96
#   eval: bucket 2 perplexity 3.13
#   eval: bucket 3 perplexity 3.02
# Testing the model
# global step 12800 learning rate 0.0443 step-time 0.07 perplexity 6.23
#   eval: bucket 0 perplexity 4.50
#   eval: bucket 1 perplexity 6.83
#   eval: bucket 2 perplexity 3.62
#   eval: bucket 3 perplexity 9.46
# Testing the model
# global step 13000 learning rate 0.0439 step-time 0.07 perplexity 6.16
#   eval: bucket 0 perplexity 18.77
#   eval: bucket 1 perplexity 4.69
#   eval: bucket 2 perplexity 8.38
#   eval: bucket 3 perplexity 7.20
# Testing the model
# global step 13200 learning rate 0.0439 step-time 0.07 perplexity 5.93
#   eval: bucket 0 perplexity 55.26
#   eval: bucket 1 perplexity 12.32
#   eval: bucket 2 perplexity 4.69
#   eval: bucket 3 perplexity 3.17
# Testing the model
# global step 13400 learning rate 0.0439 step-time 0.07 perplexity 6.00
#   eval: bucket 0 perplexity 1.98
#   eval: bucket 1 perplexity 2.16
#   eval: bucket 2 perplexity 5.01
#   eval: bucket 3 perplexity 3.55
# Testing the model
# global step 13600 learning rate 0.0439 step-time 0.07 perplexity 6.03
#   eval: bucket 0 perplexity 12.90
#   eval: bucket 1 perplexity 13.16
#   eval: bucket 2 perplexity 18.55
#   eval: bucket 3 perplexity 4.99
# Testing the model
# global step 13800 learning rate 0.0439 step-time 0.07 perplexity 5.73
#   eval: bucket 0 perplexity 8.51
#   eval: bucket 1 perplexity 7.84
#   eval: bucket 2 perplexity 10.67
#   eval: bucket 3 perplexity 8.82
# Testing the model
# global step 14000 learning rate 0.0439 step-time 0.07 perplexity 5.87
#   eval: bucket 0 perplexity 5.79
#   eval: bucket 1 perplexity 3.28
#   eval: bucket 2 perplexity 6.26
#   eval: bucket 3 perplexity 7.74
# Testing the model
# global step 14200 learning rate 0.0439 step-time 0.07 perplexity 5.94
#   eval: bucket 0 perplexity 12.57
#   eval: bucket 1 perplexity 5.08
#   eval: bucket 2 perplexity 3.94
#   eval: bucket 3 perplexity 5.04
# Testing the model
# global step 14400 learning rate 0.0439 step-time 0.07 perplexity 5.88
#   eval: bucket 0 perplexity 22.64
#   eval: bucket 1 perplexity 4.73
#   eval: bucket 2 perplexity 8.47
#   eval: bucket 3 perplexity 6.34
# Testing the model
# global step 14600 learning rate 0.0439 step-time 0.07 perplexity 6.00
#   eval: bucket 0 perplexity 7.41
#   eval: bucket 1 perplexity 7.54
#   eval: bucket 2 perplexity 5.83
#   eval: bucket 3 perplexity 10.78
# Testing the model
# global step 14800 learning rate 0.0434 step-time 0.06 perplexity 5.73
#   eval: bucket 0 perplexity 4.04
#   eval: bucket 1 perplexity 4.42
#   eval: bucket 2 perplexity 3.27
#   eval: bucket 3 perplexity 4.47
# Testing the model
# global step 15000 learning rate 0.0434 step-time 0.07 perplexity 5.47
#   eval: bucket 0 perplexity 2.25
#   eval: bucket 1 perplexity 2.38
#   eval: bucket 2 perplexity 7.97
#   eval: bucket 3 perplexity 9.23
# Testing the model
# global step 15200 learning rate 0.0434 step-time 0.07 perplexity 5.63
#   eval: bucket 0 perplexity 2.22
#   eval: bucket 1 perplexity 9.99
#   eval: bucket 2 perplexity 10.74
#   eval: bucket 3 perplexity 4.29
# Testing the model
# global step 15400 learning rate 0.0434 step-time 0.07 perplexity 5.58
#   eval: bucket 0 perplexity 2.77
#   eval: bucket 1 perplexity 6.95
#   eval: bucket 2 perplexity 14.03
#   eval: bucket 3 perplexity 4.67
# Testing the model
# global step 15600 learning rate 0.0434 step-time 0.06 perplexity 5.27
#   eval: bucket 0 perplexity 2.78
#   eval: bucket 1 perplexity 2.45
#   eval: bucket 2 perplexity 6.98
#   eval: bucket 3 perplexity 4.50
# Testing the model
# global step 15800 learning rate 0.0434 step-time 0.07 perplexity 5.93
#   eval: bucket 0 perplexity 10.84
#   eval: bucket 1 perplexity 3.20
#   eval: bucket 2 perplexity 3.40
#   eval: bucket 3 perplexity 6.34
# Testing the model
# global step 16000 learning rate 0.0430 step-time 0.07 perplexity 5.57
#   eval: bucket 0 perplexity 11.11
#   eval: bucket 1 perplexity 3.34
#   eval: bucket 2 perplexity 10.21
#   eval: bucket 3 perplexity 5.06
# Testing the model
# global step 16200 learning rate 0.0430 step-time 0.07 perplexity 6.15
#   eval: bucket 0 perplexity 2.48
#   eval: bucket 1 perplexity 4.74
#   eval: bucket 2 perplexity 6.03
#   eval: bucket 3 perplexity 4.87
# Testing the model
# global step 16400 learning rate 0.0426 step-time 0.07 perplexity 5.70
#   eval: bucket 0 perplexity 2.33
#   eval: bucket 1 perplexity 3.42
#   eval: bucket 2 perplexity 3.69
#   eval: bucket 3 perplexity 3.45
# Testing the model
# global step 16600 learning rate 0.0426 step-time 0.07 perplexity 5.50
#   eval: bucket 0 perplexity 2.03
#   eval: bucket 1 perplexity 3.51
#   eval: bucket 2 perplexity 8.72
#   eval: bucket 3 perplexity 2.57
# Testing the model
# global step 16800 learning rate 0.0426 step-time 0.07 perplexity 5.73
#   eval: bucket 0 perplexity 10.25
#   eval: bucket 1 perplexity 2.58
#   eval: bucket 2 perplexity 5.27
#   eval: bucket 3 perplexity 7.29
# Testing the model
# global step 17000 learning rate 0.0426 step-time 0.07 perplexity 6.09
#   eval: bucket 0 perplexity 4.43
#   eval: bucket 1 perplexity 15.36
#   eval: bucket 2 perplexity 12.75
#   eval: bucket 3 perplexity 4.87
# Testing the model
# global step 17200 learning rate 0.0421 step-time 0.07 perplexity 5.94
#   eval: bucket 0 perplexity 4.23
#   eval: bucket 1 perplexity 3.77
#   eval: bucket 2 perplexity 5.13
#   eval: bucket 3 perplexity 2.76
# Testing the model
# global step 17400 learning rate 0.0421 step-time 0.07 perplexity 5.85
#   eval: bucket 0 perplexity 2.42
#   eval: bucket 1 perplexity 5.05
#   eval: bucket 2 perplexity 3.84
#   eval: bucket 3 perplexity 13.46
# Testing the model
# global step 17600 learning rate 0.0421 step-time 0.07 perplexity 5.64
#   eval: bucket 0 perplexity 14.77
#   eval: bucket 1 perplexity 2.17
#   eval: bucket 2 perplexity 8.07
#   eval: bucket 3 perplexity 9.51
# Testing the model
# global step 17800 learning rate 0.0421 step-time 0.07 perplexity 5.53
#   eval: bucket 0 perplexity 1.96
#   eval: bucket 1 perplexity 1.97
#   eval: bucket 2 perplexity 7.77
#   eval: bucket 3 perplexity 8.79
# Testing the model
# global step 18000 learning rate 0.0421 step-time 0.07 perplexity 5.68
#   eval: bucket 0 perplexity 2.00
#   eval: bucket 1 perplexity 2.98
#   eval: bucket 2 perplexity 8.41
#   eval: bucket 3 perplexity 6.81
# Testing the model
# global step 18200 learning rate 0.0421 step-time 0.07 perplexity 5.61
#   eval: bucket 0 perplexity 13.58
#   eval: bucket 1 perplexity 15.15
#   eval: bucket 2 perplexity 6.26
#   eval: bucket 3 perplexity 4.70
# Testing the model
# global step 18400 learning rate 0.0421 step-time 0.07 perplexity 5.38
#   eval: bucket 0 perplexity 8.47
#   eval: bucket 1 perplexity 8.53
#   eval: bucket 2 perplexity 6.72
#   eval: bucket 3 perplexity 3.48
# Testing the model
# global step 18600 learning rate 0.0421 step-time 0.07 perplexity 5.74
#   eval: bucket 0 perplexity 2.53
#   eval: bucket 1 perplexity 5.58
#   eval: bucket 2 perplexity 4.94
#   eval: bucket 3 perplexity 3.48
# Testing the model
# global step 18800 learning rate 0.0417 step-time 0.07 perplexity 6.03
#   eval: bucket 0 perplexity 4.91
#   eval: bucket 1 perplexity 8.71
#   eval: bucket 2 perplexity 8.29
#   eval: bucket 3 perplexity 10.52
# Testing the model
# global step 19000 learning rate 0.0413 step-time 0.07 perplexity 5.71
#   eval: bucket 0 perplexity 2.69
#   eval: bucket 1 perplexity 30.36
#   eval: bucket 2 perplexity 5.20
#   eval: bucket 3 perplexity 9.63
# Testing the model
# global step 19200 learning rate 0.0413 step-time 0.07 perplexity 5.62
#   eval: bucket 0 perplexity 1.86
#   eval: bucket 1 perplexity 4.08
#   eval: bucket 2 perplexity 4.41
#   eval: bucket 3 perplexity 5.69
# Testing the model
# global step 19400 learning rate 0.0413 step-time 0.07 perplexity 5.53
#   eval: bucket 0 perplexity 2.75
#   eval: bucket 1 perplexity 12.26
#   eval: bucket 2 perplexity 5.58
#   eval: bucket 3 perplexity 4.36
# Testing the model
# global step 19600 learning rate 0.0413 step-time 0.07 perplexity 5.74
#   eval: bucket 0 perplexity 5.10
#   eval: bucket 1 perplexity 4.36
#   eval: bucket 2 perplexity 8.26
#   eval: bucket 3 perplexity 6.76
# Testing the model
# global step 19800 learning rate 0.0409 step-time 0.07 perplexity 5.41
#   eval: bucket 0 perplexity 14.19
#   eval: bucket 1 perplexity 7.27
#   eval: bucket 2 perplexity 3.50
#   eval: bucket 3 perplexity 2.97
# Testing the model
# global step 20000 learning rate 0.0409 step-time 0.07 perplexity 5.55
#   eval: bucket 0 perplexity 6.05
#   eval: bucket 1 perplexity 2.23
#   eval: bucket 2 perplexity 2.48
#   eval: bucket 3 perplexity 4.75
# Testing the model
# global step 20200 learning rate 0.0409 step-time 0.07 perplexity 5.70
#   eval: bucket 0 perplexity 17.69
#   eval: bucket 1 perplexity 2.48
#   eval: bucket 2 perplexity 5.04
#   eval: bucket 3 perplexity 5.48
# Testing the model
# global step 20400 learning rate 0.0409 step-time 0.07 perplexity 5.65
#   eval: bucket 0 perplexity 4.91
#   eval: bucket 1 perplexity 9.99
#   eval: bucket 2 perplexity 5.38
#   eval: bucket 3 perplexity 40.48
# Testing the model
# global step 20600 learning rate 0.0409 step-time 0.07 perplexity 5.44
#   eval: bucket 0 perplexity 2.89
#   eval: bucket 1 perplexity 3.64
#   eval: bucket 2 perplexity 2.42
#   eval: bucket 3 perplexity 3.56
# Testing the model
# global step 20800 learning rate 0.0409 step-time 0.07 perplexity 5.66
#   eval: bucket 0 perplexity 17.00
#   eval: bucket 1 perplexity 2.28
#   eval: bucket 2 perplexity 6.45
#   eval: bucket 3 perplexity 3.36
# Testing the model
# global step 21000 learning rate 0.0409 step-time 0.07 perplexity 5.17
#   eval: bucket 0 perplexity 2.76
#   eval: bucket 1 perplexity 2.41
#   eval: bucket 2 perplexity 4.11
#   eval: bucket 3 perplexity 3.58
# Testing the model
# global step 21200 learning rate 0.0409 step-time 0.07 perplexity 5.30
#   eval: bucket 0 perplexity 8.69
#   eval: bucket 1 perplexity 29.27
#   eval: bucket 2 perplexity 6.20
#   eval: bucket 3 perplexity 4.18
# Testing the model
# global step 21400 learning rate 0.0409 step-time 0.07 perplexity 5.09
#   eval: bucket 0 perplexity 2.20
#   eval: bucket 1 perplexity 8.52
#   eval: bucket 2 perplexity 5.13
#   eval: bucket 3 perplexity 5.52
# Testing the model
# global step 21600 learning rate 0.0409 step-time 0.07 perplexity 5.55
#   eval: bucket 0 perplexity 1.96
#   eval: bucket 1 perplexity 3.58
#   eval: bucket 2 perplexity 5.92
#   eval: bucket 3 perplexity 6.85
# Testing the model
# global step 21800 learning rate 0.0405 step-time 0.07 perplexity 5.14
#   eval: bucket 0 perplexity 2.56
#   eval: bucket 1 perplexity 1.47
#   eval: bucket 2 perplexity 3.48
#   eval: bucket 3 perplexity 2.61
# Testing the model
# global step 22000 learning rate 0.0405 step-time 0.07 perplexity 5.31
#   eval: bucket 0 perplexity 3.42
#   eval: bucket 1 perplexity 3.61
#   eval: bucket 2 perplexity 3.92
#   eval: bucket 3 perplexity 6.67
# Testing the model
# global step 22200 learning rate 0.0405 step-time 0.07 perplexity 5.78
#   eval: bucket 0 perplexity 2.44
#   eval: bucket 1 perplexity 4.64
#   eval: bucket 2 perplexity 2.51
#   eval: bucket 3 perplexity 3.76
# Testing the model
# global step 22400 learning rate 0.0401 step-time 0.07 perplexity 5.49
#   eval: bucket 0 perplexity 3.03
#   eval: bucket 1 perplexity 5.57
#   eval: bucket 2 perplexity 2.55
#   eval: bucket 3 perplexity 7.04
# Testing the model
# global step 22600 learning rate 0.0401 step-time 0.07 perplexity 5.55
#   eval: bucket 0 perplexity 2.51
#   eval: bucket 1 perplexity 2.04
#   eval: bucket 2 perplexity 3.50
#   eval: bucket 3 perplexity 3.77
# Testing the model
# global step 22800 learning rate 0.0401 step-time 0.07 perplexity 5.22
#   eval: bucket 0 perplexity 1.50
#   eval: bucket 1 perplexity 1.87
#   eval: bucket 2 perplexity 7.03
#   eval: bucket 3 perplexity 6.15
# Testing the model
# global step 23000 learning rate 0.0401 step-time 0.07 perplexity 5.18
#   eval: bucket 0 perplexity 3.30
#   eval: bucket 1 perplexity 3.74
#   eval: bucket 2 perplexity 19.61
#   eval: bucket 3 perplexity 4.73
# Testing the model
# global step 23200 learning rate 0.0401 step-time 0.07 perplexity 5.70
#   eval: bucket 0 perplexity 2.20
#   eval: bucket 1 perplexity 2.66
#   eval: bucket 2 perplexity 4.23
#   eval: bucket 3 perplexity 3.87
# Testing the model
# global step 23400 learning rate 0.0397 step-time 0.07 perplexity 5.30
#   eval: bucket 0 perplexity 2.03
#   eval: bucket 1 perplexity 5.32
#   eval: bucket 2 perplexity 4.37
#   eval: bucket 3 perplexity 4.05
# Testing the model
# global step 23600 learning rate 0.0397 step-time 0.07 perplexity 5.79
#   eval: bucket 0 perplexity 2.75
#   eval: bucket 1 perplexity 3.66
#   eval: bucket 2 perplexity 3.67
#   eval: bucket 3 perplexity 10.47
# Testing the model
# global step 23800 learning rate 0.0393 step-time 0.07 perplexity 5.45
#   eval: bucket 0 perplexity 2.60
#   eval: bucket 1 perplexity 7.35
#   eval: bucket 2 perplexity 7.45
#   eval: bucket 3 perplexity 10.94
# Testing the model
# global step 24000 learning rate 0.0393 step-time 0.07 perplexity 5.23
#   eval: bucket 0 perplexity 18.54
#   eval: bucket 1 perplexity 13.39
#   eval: bucket 2 perplexity 4.59
#   eval: bucket 3 perplexity 2.95
# Testing the model
# global step 24200 learning rate 0.0393 step-time 0.07 perplexity 5.49
#   eval: bucket 0 perplexity 3.82
#   eval: bucket 1 perplexity 2.37
#   eval: bucket 2 perplexity 2.96
#   eval: bucket 3 perplexity 4.01
# Testing the model
# global step 24400 learning rate 0.0393 step-time 0.07 perplexity 5.30
#   eval: bucket 0 perplexity 8.43
#   eval: bucket 1 perplexity 2.40
#   eval: bucket 2 perplexity 11.27
#   eval: bucket 3 perplexity 4.13
# Testing the model
# global step 24600 learning rate 0.0393 step-time 0.07 perplexity 5.50
#   eval: bucket 0 perplexity 2.17
#   eval: bucket 1 perplexity 3.55
#   eval: bucket 2 perplexity 2.89
#   eval: bucket 3 perplexity 4.34
# Testing the model
# global step 24800 learning rate 0.0389 step-time 0.06 perplexity 5.46
#   eval: bucket 0 perplexity 1.61
#   eval: bucket 1 perplexity 12.43
#   eval: bucket 2 perplexity 7.67
#   eval: bucket 3 perplexity 4.90
# Testing the model
# global step 25000 learning rate 0.0389 step-time 0.07 perplexity 5.16
#   eval: bucket 0 perplexity 4.99
#   eval: bucket 1 perplexity 7.34
#   eval: bucket 2 perplexity 4.84
#   eval: bucket 3 perplexity 5.76
# Testing the model
# global step 25200 learning rate 0.0389 step-time 0.07 perplexity 4.68
#   eval: bucket 0 perplexity 3.31
#   eval: bucket 1 perplexity 3.09
#   eval: bucket 2 perplexity 9.30
#   eval: bucket 3 perplexity 7.11
# Testing the model
# global step 25400 learning rate 0.0389 step-time 0.07 perplexity 5.24
#   eval: bucket 0 perplexity 1.97
#   eval: bucket 1 perplexity 3.48
#   eval: bucket 2 perplexity 2.61
#   eval: bucket 3 perplexity 7.04
# Testing the model
# global step 25600 learning rate 0.0389 step-time 0.07 perplexity 5.39
#   eval: bucket 0 perplexity 1.71
#   eval: bucket 1 perplexity 5.90
#   eval: bucket 2 perplexity 3.59
#   eval: bucket 3 perplexity 15.77
# Testing the model
# global step 25800 learning rate 0.0385 step-time 0.07 perplexity 5.21
#   eval: bucket 0 perplexity 2.80
#   eval: bucket 1 perplexity 3.20
#   eval: bucket 2 perplexity 7.91
#   eval: bucket 3 perplexity 3.12
# Testing the model
# global step 26000 learning rate 0.0385 step-time 0.07 perplexity 5.44
#   eval: bucket 0 perplexity 2.91
#   eval: bucket 1 perplexity 4.49
#   eval: bucket 2 perplexity 6.23
#   eval: bucket 3 perplexity 4.36
# Testing the model
# global step 26200 learning rate 0.0381 step-time 0.07 perplexity 5.39
#   eval: bucket 0 perplexity 3.54
#   eval: bucket 1 perplexity 5.63
#   eval: bucket 2 perplexity 4.27
#   eval: bucket 3 perplexity 6.43
# Testing the model
# global step 26400 learning rate 0.0381 step-time 0.07 perplexity 5.06
#   eval: bucket 0 perplexity 2.89
#   eval: bucket 1 perplexity 9.73
#   eval: bucket 2 perplexity 6.86
#   eval: bucket 3 perplexity 2.45
# Testing the model
# global step 26600 learning rate 0.0381 step-time 0.07 perplexity 5.25
#   eval: bucket 0 perplexity 3.75
#   eval: bucket 1 perplexity 2.89
#   eval: bucket 2 perplexity 6.09
#   eval: bucket 3 perplexity 7.81
# Testing the model
# global step 26800 learning rate 0.0381 step-time 0.07 perplexity 5.09
#   eval: bucket 0 perplexity 3.50
#   eval: bucket 1 perplexity 1.85
#   eval: bucket 2 perplexity 10.59
#   eval: bucket 3 perplexity 4.61
# Testing the model
# global step 27000 learning rate 0.0381 step-time 0.07 perplexity 5.52
#   eval: bucket 0 perplexity 2.15
#   eval: bucket 1 perplexity 13.13
#   eval: bucket 2 perplexity 2.51
#   eval: bucket 3 perplexity 5.34
# Testing the model
# global step 27200 learning rate 0.0377 step-time 0.07 perplexity 5.37
#   eval: bucket 0 perplexity 5.65
#   eval: bucket 1 perplexity 2.77
#   eval: bucket 2 perplexity 11.53
#   eval: bucket 3 perplexity 4.96
# Testing the model
# global step 27400 learning rate 0.0377 step-time 0.07 perplexity 5.08
#   eval: bucket 0 perplexity 3.40
#   eval: bucket 1 perplexity 3.90
#   eval: bucket 2 perplexity 9.95
#   eval: bucket 3 perplexity 10.98
# Testing the model
# global step 27600 learning rate 0.0377 step-time 0.07 perplexity 5.06
#   eval: bucket 0 perplexity 8.58
#   eval: bucket 1 perplexity 3.93
#   eval: bucket 2 perplexity 5.33
#   eval: bucket 3 perplexity 23.65
# Testing the model
# global step 27800 learning rate 0.0377 step-time 0.07 perplexity 5.50
#   eval: bucket 0 perplexity 2.48
#   eval: bucket 1 perplexity 2.08
#   eval: bucket 2 perplexity 3.78
#   eval: bucket 3 perplexity 2.54
# Testing the model
# global step 28000 learning rate 0.0374 step-time 0.07 perplexity 5.16
#   eval: bucket 0 perplexity 1.45
#   eval: bucket 1 perplexity 8.76
#   eval: bucket 2 perplexity 3.66
#   eval: bucket 3 perplexity 5.91
# Testing the model
# global step 28200 learning rate 0.0374 step-time 0.07 perplexity 5.28
#   eval: bucket 0 perplexity 16.97
#   eval: bucket 1 perplexity 5.22
#   eval: bucket 2 perplexity 7.10
#   eval: bucket 3 perplexity 8.41
# Testing the model
# global step 28400 learning rate 0.0374 step-time 0.07 perplexity 5.21
#   eval: bucket 0 perplexity 2.31
#   eval: bucket 1 perplexity 8.40
#   eval: bucket 2 perplexity 7.87
#   eval: bucket 3 perplexity 4.70
# Testing the model
# global step 28600 learning rate 0.0374 step-time 0.07 perplexity 5.01
#   eval: bucket 0 perplexity 5.03
#   eval: bucket 1 perplexity 1.73
#   eval: bucket 2 perplexity 5.82
#   eval: bucket 3 perplexity 5.20
# Testing the model
# global step 28800 learning rate 0.0374 step-time 0.07 perplexity 5.11
#   eval: bucket 0 perplexity 1.91
#   eval: bucket 1 perplexity 5.07
#   eval: bucket 2 perplexity 3.74
#   eval: bucket 3 perplexity 3.56
# Testing the model
# global step 29000 learning rate 0.0374 step-time 0.07 perplexity 4.96
#   eval: bucket 0 perplexity 6.46
#   eval: bucket 1 perplexity 4.28
#   eval: bucket 2 perplexity 4.35
#   eval: bucket 3 perplexity 7.16
# Testing the model
# global step 29200 learning rate 0.0374 step-time 0.07 perplexity 5.39
#   eval: bucket 0 perplexity 3.70
#   eval: bucket 1 perplexity 15.68
#   eval: bucket 2 perplexity 2.97
#   eval: bucket 3 perplexity 4.36
# Testing the model
# global step 29400 learning rate 0.0370 step-time 0.07 perplexity 4.99
#   eval: bucket 0 perplexity 1.75
#   eval: bucket 1 perplexity 2.18
#   eval: bucket 2 perplexity 6.55
#   eval: bucket 3 perplexity 7.29
# Testing the model
# global step 29600 learning rate 0.0370 step-time 0.07 perplexity 5.11
#   eval: bucket 0 perplexity 3.07
#   eval: bucket 1 perplexity 15.27
#   eval: bucket 2 perplexity 12.37
#   eval: bucket 3 perplexity 7.05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-74e7f6375b41> in <module>()
#       3 with tf.Session() as sess:
#       4     model = create_model(sess, conf=config)
# ----> 5     model = train(sess, model, data)
#
# /home/vasanth/programming/690N/project/conversational_agent_personified/src/converse.pyc in train(session, model, train_data)
#     153 		train_set, bucket_id)
#     154 		_, step_loss, _ = model.step(session, encoder_inputs, decoder_inputs,
# --> 155 		                       target_weights, bucket_id, False)
#     156                 step_time += (time.time() - start_time) / STEPS_PER_CHECKPOINT
#     157                 loss += step_loss / STEPS_PER_CHECKPOINT
#
# /home/vasanth/programming/690N/project/conversational_agent_personified/src/seq2seq_model.pyc in step(self, session, encoder_inputs, decoder_inputs, target_weights, bucket_id, forward_only)
#     260         output_feed.append(self.outputs[bucket_id][l])
#     261
# --> 262     outputs = session.run(output_feed, input_feed)
#     263     if not forward_only:
#     264       return outputs[1], outputs[2], None  # Gradient norm, loss, no outputs.
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     938           np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#     939
# --> 940           if not subfeed_t.get_shape().is_compatible_with(np_val.shape):
#     941             raise ValueError(
#     942                 'Cannot feed value of shape %r for Tensor %r, '
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/tensor_shape.pyc in is_compatible_with(self, other)
#     711
#     712     """
# --> 713     other = as_shape(other)
#     714     if self._dims is not None and other.dims is not None:
#     715       if self.ndims != other.ndims:
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/tensor_shape.pyc in as_shape(shape)
#     798     return shape
#     799   else:
# --> 800     return TensorShape(shape)
#     801
#     802
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/tensor_shape.pyc in __init__(self, dims)
#     434       else:
#     435         # Got a list of dimensions
# --> 436         self._dims = [as_dimension(d) for d in dims_iter]
#     437
#     438   def __repr__(self):
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/tensor_shape.pyc in as_dimension(value)
#     376     return value
#     377   else:
# --> 378     return Dimension(value)
#     379
#     380
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/framework/tensor_shape.pyc in __init__(self, value)
#      35           and self._value != value):
#      36         raise ValueError("Ambiguous dimension: %s" % value)
# ---> 37       if self._value < 0:
#      38         raise ValueError("Dimension %d must be >= 0" % self._value)
#      39
#
# KeyboardInterrupt:

# %% [markdown]
# # Test

# %%
import string
from nltk.stem.porter import *
stemmer = PorterStemmer()
replace_punctuation = string.maketrans(string.punctuation, ' '*len(string.punctuation))
def process(sent):
    sent = sent.strip().lower()
    sent = sent.translate(replace_punctuation)
    dialog = ''
    for w in sent.split():
        if not w.isalpha():
            w = 'DIGIT'
#         else:
#             try:
#                 w = stemmer.stem(w)
#             except:
#                 pass
        dialog += w + ' '
    print "Your dialog:", dialog
    return dialog

# %%
config['test'] = True
with tf.Session() as sess:
    model = create_model(sess, conf=config)
    while True:
        sent = raw_input("You: ")
        sent = process(sent)
        print "Bot:",test(sess, model, sent)
# Out:
# Creating 256  of 1 layers
# 66533 256
# Reading model parameters from ../models/chatbot.ckpt-29600
